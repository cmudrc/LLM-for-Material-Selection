# %%
import pandas as pd

# %%
df = pd.read_csv('/Users/yashpatawari/LLM-for-Material-Selection/Clean_Responses_All.csv')
df.head()
# Out:
#   material_familiarity  yrs_experience  Q1_Steel  Q1_Aluminium  Q1_Titanium  \
# 0                   No             0.0         0             0            0
# 1                  Yes             4.0         7             8            8
# 2                  Yes            30.0         7             9            9
# 3                  Yes             7.0         2             8            9
# 4                  Yes             7.0         5             9            4
#
#    Q1_Glass  Q1_Wood  Q1_Thermoplastic  Q1_Elastomer  Q1_Thermoset  ...  \
# 0         0        0                 0             0             0  ...
# 1         0        9                 7             6             7  ...
# 2         1        8                 5             4             9  ...
# 3         1       10                 6             6             4  ...
# 4         0        9                 4             8            10  ...
#
# ...

# %%
import matplotlib.pyplot as plt

# %%
materials = ["Steel", "Aluminium", "Titanium", "Glass", "Wood", "Thermoplastic", "Elastomer", "Thermoset", "Composite"]
print(len(materials))
# Out:
# 9

# %%
import seaborn as sns

sns.histplot(df['Q1_Steel'])
# Out:
# <Axes: xlabel='Q1_Steel', ylabel='Count'>

# %%
# for m in materials:
#     for i in range(1, 17):
#         sns.histplot(df['Q'+str(i)+'_'+m])
#         plt.show()

# %%
materials = ["Steel", "Aluminium", "Titanium", "Glass", "Wood", "Thermoplastic", "Elastomer", "Thermoset", "Composite"]
print(len(materials))
# Out:
# 9

# %%
mean_list_steel_total = []
for i in range(1,17):
    mean_list_steel_total.append(df[f"Q{i}_Steel"].mean())
    
print(mean_list_steel_total)

length = len(mean_list_steel_total)
summation = sum(mean_list_steel_total)

mean_steel_total = summation/length
print(mean_steel_total)
# Out:
# [2.96875, 4.390625, 3.796875, 7.203125, 3.421875, 5.46875, 3.96875, 6.8125, 3.59375, 6.5625, 3.859375, 6.78125, 2.21875, 4.109375, 3.203125, 5.828125]
# 4.63671875

# %%
mean_list_aluminium_total = []
for i in range(1,17):
    mean_list_aluminium_total.append(df[f"Q{i}_Aluminium"].mean())
    
print(mean_list_aluminium_total)

length = len(mean_list_aluminium_total)
summation = sum(mean_list_aluminium_total)

mean_aluminium_total = summation/length
print(mean_aluminium_total)
# Out:
# [6.109375, 4.75, 6.15625, 6.296875, 7.125, 5.375, 7.046875, 6.515625, 6.34375, 5.671875, 6.421875, 5.90625, 5.140625, 4.375, 5.78125, 5.9375]
# 5.9345703125

# %%
mean_list_titanium_total = []
for i in range(1, 17):
    mean_list_titanium_total.append(df[f"Q{i}_Titanium"].mean())

print(mean_list_titanium_total)

length = len(mean_list_titanium_total)
summation = sum(mean_list_titanium_total)

mean_titanium_total = summation / length
print(mean_titanium_total)
# Out:
# [5.140625, 4.90625, 7.109375, 7.671875, 6.84375, 7.46875, 8.03125, 8.6875, 7.328125, 7.96875, 8.15625, 8.109375, 5.25, 5.59375, 6.390625, 7.1875]
# 6.990234375

# %%
mean_list_glass_total = []
for i in range(1, 17):
    mean_list_glass_total.append(df[f"Q{i}_Glass"].mean())

print(mean_list_glass_total)

length = len(mean_list_glass_total)
summation = sum(mean_list_glass_total)

mean_glass_total = summation / length
print(mean_glass_total)
# Out:
# [2.265625, 4.53125, 6.484375, 2.828125, 2.15625, 4.09375, 5.578125, 2.21875, 2.953125, 4.421875, 6.109375, 2.484375, 1.15625, 2.609375, 3.3125, 1.578125]
# 3.423828125

# %%
mean_list_wood_total = []
for i in range(1, 17):
    mean_list_wood_total.append(df[f"Q{i}_Wood"].mean())

print(mean_list_wood_total)

length = len(mean_list_wood_total)
summation = sum(mean_list_wood_total)

mean_wood_total = summation / length
print(mean_wood_total)
# Out:
# [6.015625, 5.109375, 5.765625, 4.8125, 2.28125, 1.328125, 2.96875, 1.796875, 2.078125, 1.96875, 2.71875, 1.84375, 2.765625, 3.171875, 3.140625, 2.546875]
# 3.14453125

# %%
mean_list_thermoplastic_total = []
for i in range(1, 17):
    mean_list_thermoplastic_total.append(df[f"Q{i}_Thermoplastic"].mean())

print(mean_list_thermoplastic_total)

length = len(mean_list_thermoplastic_total)
summation = sum(mean_list_thermoplastic_total)

mean_thermoplastic_total = summation / length
print(mean_thermoplastic_total)
# Out:
# [5.484375, 4.15625, 6.71875, 4.4375, 4.671875, 2.84375, 5.5625, 3.265625, 4.203125, 2.9375, 5.5625, 3.1875, 6.109375, 4.390625, 6.765625, 5.03125]
# 4.7080078125

# %%
mean_list_elastomer_total = []
for i in range(1, 17):
    mean_list_elastomer_total.append(df[f"Q{i}_Elastomer"].mean())

print(mean_list_elastomer_total)

length = len(mean_list_elastomer_total)
summation = sum(mean_list_elastomer_total)

mean_elastomer_total = summation / length
print(mean_elastomer_total)
# Out:
# [4.671875, 3.625, 5.984375, 3.21875, 3.421875, 2.03125, 4.828125, 2.0625, 3.46875, 2.453125, 4.421875, 2.203125, 4.40625, 3.84375, 5.328125, 3.140625]
# 3.6943359375

# %%
mean_list_thermoset_total = []
for i in range(1, 17):
    mean_list_thermoset_total.append(df[f"Q{i}_Thermoset"].mean())

print(mean_list_thermoset_total)

length = len(mean_list_thermoset_total)
summation = sum(mean_list_thermoset_total)

mean_thermoset_total = summation / length
print(mean_thermoset_total)
# Out:
# [5.8125, 5.25, 6.359375, 4.640625, 4.296875, 3.15625, 5.578125, 3.421875, 4.234375, 3.3125, 5.359375, 3.765625, 4.625, 5.046875, 5.65625, 4.765625]
# 4.705078125

# %%
mean_list_composite_total = []
for i in range(1, 17):
    mean_list_composite_total.append(df[f"Q{i}_Composite"].mean())

print(mean_list_composite_total)

length = len(mean_list_composite_total)
summation = sum(mean_list_composite_total)

mean_composite_total = summation / length
print(mean_composite_total)
# Out:
# [7.046875, 5.875, 7.46875, 6.984375, 7.90625, 5.796875, 7.5625, 7.546875, 7.46875, 5.609375, 7.328125, 6.578125, 8.46875, 7.265625, 8.046875, 8.390625]
# 7.208984375

# %%
df.head()
# Out:
#   material_familiarity  yrs_experience  Q1_Steel  Q1_Aluminium  Q1_Titanium  \
# 0                   No             0.0         0             0            0
# 1                  Yes             4.0         7             8            8
# 2                  Yes            30.0         7             9            9
# 3                  Yes             7.0         2             8            9
# 4                  Yes             7.0         5             9            4
#
#    Q1_Glass  Q1_Wood  Q1_Thermoplastic  Q1_Elastomer  Q1_Thermoset  ...  \
# 0         0        0                 0             0             0  ...
# 1         0        9                 7             6             7  ...
# 2         1        8                 5             4             9  ...
# 3         1       10                 6             6             4  ...
# 4         0        9                 4             8            10  ...
#
# ...

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], marker='o', linestyle='-', color='b')
# colors = ['b', 'g', 'r', 'c', 'm', 'y', 'k', 'orange', 'purple']

# plt.figure(figsize=(10, 8))
# plt.plot(materials, [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], marker='o', linestyle='-', color=colors)

plt.xlabel('Materials', fontsize=12)
# plt.ylabel('Scores from Survey', fontsize=12)
# plt.ylim(0, 10)

# # Add value of each marker
# for i, j, color in zip(materials, [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], colors):
#     plt.text(i, j, str(j), ha='center', va='bottom', color=color)

# plt.show()
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
for i, j in zip(materials, [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total]):
    plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Design Case

# %%
mean_list_kitchen = []
mean_list_steel_kitchen = []
mean_list_aluminium_kitchen = []
mean_list_titanium_kitchen = []
mean_list_glass_kitchen = []
mean_list_wood_kitchen = []
mean_list_thermoplastic_kitchen = []
mean_list_elastomer_kitchen = []
mean_list_thermoset_kitchen = []
mean_list_composite_kitchen = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_kitchen.append(df[f"Q1_{m}"].mean())
        mean_list_steel_kitchen.append(df[f"Q2_{m}"].mean())
        mean_list_steel_kitchen.append(df[f"Q3_{m}"].mean())
        mean_list_steel_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Aluminium":
            mean_list_aluminium_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_aluminium_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_aluminium_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_aluminium_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Titanium":
            mean_list_titanium_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_titanium_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_titanium_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_titanium_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Glass":
            mean_list_glass_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_glass_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_glass_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_glass_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Wood":
            mean_list_wood_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_wood_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_wood_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_wood_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Thermoplastic":
            mean_list_thermoplastic_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_thermoplastic_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_thermoplastic_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_thermoplastic_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Elastomer":
            mean_list_elastomer_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_elastomer_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_elastomer_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_elastomer_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Thermoset":
            mean_list_thermoset_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_thermoset_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_thermoset_kitchen.append(df[f"Q3_{m}"].mean())
            mean_list_thermoset_kitchen.append(df[f"Q4_{m}"].mean())
    elif m == "Composite":
            mean_list_composite_kitchen.append(df[f"Q4_{m}"].mean())
            mean_list_composite_kitchen.append(df[f"Q1_{m}"].mean())
            mean_list_composite_kitchen.append(df[f"Q2_{m}"].mean())
            mean_list_composite_kitchen.append(df[f"Q3_{m}"].mean())

print(mean_list_composite_kitchen)


mean_kitchen_steel = sum(mean_list_steel_kitchen) / len(mean_list_steel_kitchen)
mean_kitchen_aluminium = sum(mean_list_aluminium_kitchen) / len(mean_list_aluminium_kitchen)
mean_kitchen_titanium = sum(mean_list_titanium_kitchen) / len(mean_list_titanium_kitchen)
mean_kitchen_glass = sum(mean_list_glass_kitchen) / len(mean_list_glass_kitchen)
mean_kitchen_wood = sum(mean_list_wood_kitchen) / len(mean_list_wood_kitchen)
mean_kitchen_thermoplastic = sum(mean_list_thermoplastic_kitchen) / len(mean_list_thermoplastic_kitchen)
mean_kitchen_elastomer = sum(mean_list_elastomer_kitchen) / len(mean_list_elastomer_kitchen)
mean_kitchen_thermoset = sum(mean_list_thermoset_kitchen) / len(mean_list_thermoset_kitchen)
mean_kitchen_composite = sum(mean_list_composite_kitchen) / len(mean_list_composite_kitchen)

print(mean_kitchen_composite)
# length = len(mean_list_composite_total)
# summation = sum(mean_list_composite_total)

# mean_composite_total = summation / length
# print(mean_composite_total)
# Out:
# [6.984375, 7.046875, 5.875, 7.46875]
# 6.84375

# %%
plt.figure(figsize=(10, 8))

plt.plot(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite], marker='o', linestyle='-', color='r')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Case 1: Kitchen Utensil Grip', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_spacecraft = []
mean_list_steel_spacecraft = []
mean_list_aluminium_spacecraft = []
mean_list_titanium_spacecraft = []
mean_list_glass_spacecraft = []
mean_list_wood_spacecraft = []
mean_list_thermoplastic_spacecraft = []
mean_list_elastomer_spacecraft = []
mean_list_thermoset_spacecraft = []
mean_list_composite_spacecraft = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_steel_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_steel_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_steel_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_aluminium_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_aluminium_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_aluminium_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_titanium_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_titanium_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_titanium_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_glass_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_glass_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_glass_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_wood_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_wood_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_wood_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_thermoplastic_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_thermoplastic_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_thermoplastic_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_elastomer_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_elastomer_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_elastomer_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_thermoset_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_thermoset_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_thermoset_spacecraft.append(df[f"Q8_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_spacecraft.append(df[f"Q5_{m}"].mean())
        mean_list_composite_spacecraft.append(df[f"Q6_{m}"].mean())
        mean_list_composite_spacecraft.append(df[f"Q7_{m}"].mean())
        mean_list_composite_spacecraft.append(df[f"Q8_{m}"].mean())

print(mean_list_composite_spacecraft)


mean_spacecraft_steel = sum(mean_list_steel_spacecraft) / len(mean_list_steel_spacecraft)
mean_spacecraft_aluminium = sum(mean_list_aluminium_spacecraft) / len(mean_list_aluminium_spacecraft)
mean_spacecraft_titanium = sum(mean_list_titanium_spacecraft) / len(mean_list_titanium_spacecraft)
mean_spacecraft_glass = sum(mean_list_glass_spacecraft) / len(mean_list_glass_spacecraft)
mean_spacecraft_wood = sum(mean_list_wood_spacecraft) / len(mean_list_wood_spacecraft)
mean_spacecraft_thermoplastic = sum(mean_list_thermoplastic_spacecraft) / len(mean_list_thermoplastic_spacecraft)
mean_spacecraft_elastomer = sum(mean_list_elastomer_spacecraft) / len(mean_list_elastomer_spacecraft)
mean_spacecraft_thermoset = sum(mean_list_thermoset_spacecraft) / len(mean_list_thermoset_spacecraft)
mean_spacecraft_composite = sum(mean_list_composite_spacecraft) / len(mean_list_composite_spacecraft)

print(mean_spacecraft_composite)
# Out:
# [7.90625, 5.796875, 7.5625, 7.546875]
# 7.203125

# %%
plt.figure(figsize=(10, 8))

plt.plot(materials, [mean_spacecraft_steel, mean_spacecraft_aluminium, mean_spacecraft_titanium, mean_spacecraft_glass, mean_spacecraft_wood, mean_spacecraft_thermoplastic, mean_spacecraft_elastomer, mean_spacecraft_thermoset, mean_spacecraft_composite], marker='o', linestyle='-', color='g')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Case 2: Spacecraft Component', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_underwater = []

mean_list_steel_underwater = []
mean_list_aluminium_underwater = []
mean_list_titanium_underwater = []
mean_list_glass_underwater = []
mean_list_wood_underwater = []
mean_list_thermoplastic_underwater = []
mean_list_elastomer_underwater = []
mean_list_thermoset_underwater = []
mean_list_composite_underwater = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_steel_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_steel_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_steel_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_aluminium_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_aluminium_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_aluminium_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_titanium_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_titanium_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_titanium_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_glass_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_glass_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_glass_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_wood_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_wood_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_wood_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_thermoplastic_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_thermoplastic_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_thermoplastic_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_elastomer_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_elastomer_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_elastomer_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_thermoset_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_thermoset_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_thermoset_underwater.append(df[f"Q12_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_underwater.append(df[f"Q9_{m}"].mean())
        mean_list_composite_underwater.append(df[f"Q10_{m}"].mean())
        mean_list_composite_underwater.append(df[f"Q11_{m}"].mean())
        mean_list_composite_underwater.append(df[f"Q12_{m}"].mean())

print(mean_list_composite_underwater)

mean_underwater_steel = sum(mean_list_steel_underwater) / len(mean_list_steel_underwater)
mean_underwater_aluminium = sum(mean_list_aluminium_underwater) / len(mean_list_aluminium_underwater)
mean_underwater_titanium = sum(mean_list_titanium_underwater) / len(mean_list_titanium_underwater)
mean_underwater_glass = sum(mean_list_glass_underwater) / len(mean_list_glass_underwater)
mean_underwater_wood = sum(mean_list_wood_underwater) / len(mean_list_wood_underwater)
mean_underwater_thermoplastic = sum(mean_list_thermoplastic_underwater) / len(mean_list_thermoplastic_underwater)
mean_underwater_elastomer = sum(mean_list_elastomer_underwater) / len(mean_list_elastomer_underwater)
mean_underwater_thermoset = sum(mean_list_thermoset_underwater) / len(mean_list_thermoset_underwater)
mean_underwater_composite = sum(mean_list_composite_underwater) / len(mean_list_composite_underwater)

print(mean_underwater_composite)
# Out:
# [7.46875, 5.609375, 7.328125, 6.578125]
# 6.74609375

# %%
plt.figure(figsize=(10, 8))

plt.plot(materials, [mean_underwater_steel, mean_underwater_aluminium, mean_underwater_titanium, mean_underwater_glass, mean_underwater_wood, mean_underwater_thermoplastic, mean_underwater_elastomer, mean_underwater_thermoset, mean_underwater_composite], marker='o', linestyle='-', color='y')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Case 3: Underwater Component', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_helmet = []

mean_list_steel_helmet = []
mean_list_aluminium_helmet = []
mean_list_titanium_helmet = []
mean_list_glass_helmet = []
mean_list_wood_helmet = []
mean_list_thermoplastic_helmet = []
mean_list_elastomer_helmet = []
mean_list_thermoset_helmet = []
mean_list_composite_helmet = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_steel_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_steel_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_steel_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_aluminium_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_aluminium_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_aluminium_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_titanium_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_titanium_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_titanium_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_glass_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_glass_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_glass_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_wood_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_wood_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_wood_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_thermoplastic_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_thermoplastic_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_thermoplastic_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_elastomer_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_elastomer_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_elastomer_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_thermoset_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_thermoset_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_thermoset_helmet.append(df[f"Q16_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_helmet.append(df[f"Q13_{m}"].mean())
        mean_list_composite_helmet.append(df[f"Q14_{m}"].mean())
        mean_list_composite_helmet.append(df[f"Q15_{m}"].mean())
        mean_list_composite_helmet.append(df[f"Q16_{m}"].mean())

print(mean_list_composite_helmet)

mean_helmet_steel = sum(mean_list_steel_helmet) / len(mean_list_steel_helmet)
mean_helmet_aluminium = sum(mean_list_aluminium_helmet) / len(mean_list_aluminium_helmet)
mean_helmet_titanium = sum(mean_list_titanium_helmet) / len(mean_list_titanium_helmet)
mean_helmet_glass = sum(mean_list_glass_helmet) / len(mean_list_glass_helmet)
mean_helmet_wood = sum(mean_list_wood_helmet) / len(mean_list_wood_helmet)
mean_helmet_thermoplastic = sum(mean_list_thermoplastic_helmet) / len(mean_list_thermoplastic_helmet)
mean_helmet_elastomer = sum(mean_list_elastomer_helmet) / len(mean_list_elastomer_helmet)
mean_helmet_thermoset = sum(mean_list_thermoset_helmet) / len(mean_list_thermoset_helmet)
mean_helmet_composite = sum(mean_list_composite_helmet) / len(mean_list_composite_helmet)

print(mean_helmet_composite)
# Out:
# [8.46875, 7.265625, 8.046875, 8.390625]
# 8.04296875

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_helmet_steel, mean_helmet_aluminium, mean_helmet_titanium, mean_helmet_glass, mean_helmet_wood, mean_helmet_thermoplastic, mean_helmet_elastomer, mean_helmet_thermoset, mean_helmet_composite], marker='o', linestyle='-', color='purple')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Case 4: Helmet Component', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # Criterion

# %%
mean_list_lightweight = []

mean_list_steel_lightweight = []
mean_list_aluminium_lightweight = []
mean_list_titanium_lightweight = []
mean_list_glass_lightweight = []
mean_list_wood_lightweight = []
mean_list_thermoplastic_lightweight = []
mean_list_elastomer_lightweight = []
mean_list_thermoset_lightweight = []
mean_list_composite_lightweight = []

    # for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_steel_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_steel_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_steel_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_aluminium_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_aluminium_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_aluminium_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_titanium_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_titanium_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_titanium_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_glass_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_glass_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_glass_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_wood_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_wood_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_wood_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_thermoplastic_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_thermoplastic_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_thermoplastic_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_elastomer_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_elastomer_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_elastomer_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_thermoset_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_thermoset_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_thermoset_lightweight.append(df[f"Q13_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_lightweight.append(df[f"Q1_{m}"].mean())
        mean_list_composite_lightweight.append(df[f"Q5_{m}"].mean())
        mean_list_composite_lightweight.append(df[f"Q9_{m}"].mean())
        mean_list_composite_lightweight.append(df[f"Q13_{m}"].mean())

print(mean_list_composite_lightweight)

mean_lightweight_steel = sum(mean_list_steel_lightweight) / len(mean_list_steel_lightweight)
mean_lightweight_aluminium = sum(mean_list_aluminium_lightweight) / len(mean_list_aluminium_lightweight)
mean_lightweight_titanium = sum(mean_list_titanium_lightweight) / len(mean_list_titanium_lightweight)
mean_lightweight_glass = sum(mean_list_glass_lightweight) / len(mean_list_glass_lightweight)
mean_lightweight_wood = sum(mean_list_wood_lightweight) / len(mean_list_wood_lightweight)
mean_lightweight_thermoplastic = sum(mean_list_thermoplastic_lightweight) / len(mean_list_thermoplastic_lightweight)
mean_lightweight_elastomer = sum(mean_list_elastomer_lightweight) / len(mean_list_elastomer_lightweight)
mean_lightweight_thermoset = sum(mean_list_thermoset_lightweight) / len(mean_list_thermoset_lightweight)
mean_lightweight_composite = sum(mean_list_composite_lightweight) / len(mean_list_composite_lightweight)


print(mean_lightweight_composite)
# Out:
# [7.046875, 7.90625, 7.46875, 8.46875]
# 7.72265625

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_lightweight_steel, mean_lightweight_aluminium, mean_lightweight_titanium, mean_lightweight_glass, mean_lightweight_wood, mean_lightweight_thermoplastic, mean_lightweight_elastomer, mean_lightweight_thermoset, mean_lightweight_composite], marker='o', linestyle='-', color='salmon')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Criterion 1: Lightweight', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_steel_rest_to_heat = []
mean_list_aluminium_rest_to_heat = []
mean_list_titanium_rest_to_heat = []
mean_list_glass_rest_to_heat = []
mean_list_wood_rest_to_heat = []
mean_list_thermoplastic_rest_to_heat = []
mean_list_elastomer_rest_to_heat = []
mean_list_thermoset_rest_to_heat = []
mean_list_composite_rest_to_heat = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_steel_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_steel_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_steel_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_aluminium_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_aluminium_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_aluminium_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_titanium_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_titanium_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_titanium_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_glass_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_glass_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_glass_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_wood_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_wood_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_wood_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_thermoplastic_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_thermoplastic_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_thermoplastic_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_elastomer_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_elastomer_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_elastomer_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_thermoset_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_thermoset_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_thermoset_rest_to_heat.append(df[f"Q14_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_rest_to_heat.append(df[f"Q2_{m}"].mean())
        mean_list_composite_rest_to_heat.append(df[f"Q6_{m}"].mean())
        mean_list_composite_rest_to_heat.append(df[f"Q10_{m}"].mean())
        mean_list_composite_rest_to_heat.append(df[f"Q14_{m}"].mean())

print(mean_list_composite_rest_to_heat)

mean_rest_to_heat_steel = sum(mean_list_steel_rest_to_heat) / len(mean_list_steel_rest_to_heat)
mean_rest_to_heat_aluminium = sum(mean_list_aluminium_rest_to_heat) / len(mean_list_aluminium_rest_to_heat)
mean_rest_to_heat_titanium = sum(mean_list_titanium_rest_to_heat) / len(mean_list_titanium_rest_to_heat)
mean_rest_to_heat_glass = sum(mean_list_glass_rest_to_heat) / len(mean_list_glass_rest_to_heat)
mean_rest_to_heat_wood = sum(mean_list_wood_rest_to_heat) / len(mean_list_wood_rest_to_heat)
mean_rest_to_heat_thermoplastic = sum(mean_list_thermoplastic_rest_to_heat) / len(mean_list_thermoplastic_rest_to_heat)
mean_rest_to_heat_elastomer = sum(mean_list_elastomer_rest_to_heat) / len(mean_list_elastomer_rest_to_heat)
mean_rest_to_heat_thermoset = sum(mean_list_thermoset_rest_to_heat) / len(mean_list_thermoset_rest_to_heat)
mean_rest_to_heat_composite = sum(mean_list_composite_rest_to_heat) / len(mean_list_composite_rest_to_heat)

print(mean_rest_to_heat_composite)
# Out:
# [5.875, 5.796875, 5.609375, 7.265625]
# 6.13671875

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_rest_to_heat_steel, mean_rest_to_heat_aluminium, mean_rest_to_heat_titanium, mean_rest_to_heat_glass, mean_rest_to_heat_wood, mean_rest_to_heat_thermoplastic, mean_rest_to_heat_elastomer, mean_rest_to_heat_thermoset, mean_rest_to_heat_composite], marker='o', linestyle='-', color='olivedrab')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Criterion 2: Resistant to Heat', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_steel_corrosion = []
mean_list_aluminium_corrosion = []
mean_list_titanium_corrosion = []
mean_list_glass_corrosion = []
mean_list_wood_corrosion = []
mean_list_thermoplastic_corrosion = []
mean_list_elastomer_corrosion = []
mean_list_thermoset_corrosion = []
mean_list_composite_corrosion = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_steel_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_steel_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_steel_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_aluminium_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_aluminium_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_aluminium_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_titanium_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_titanium_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_titanium_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_glass_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_glass_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_glass_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_wood_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_wood_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_wood_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_thermoplastic_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_thermoplastic_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_thermoplastic_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_elastomer_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_elastomer_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_elastomer_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_thermoset_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_thermoset_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_thermoset_corrosion.append(df[f"Q15_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_corrosion.append(df[f"Q3_{m}"].mean())
        mean_list_composite_corrosion.append(df[f"Q7_{m}"].mean())
        mean_list_composite_corrosion.append(df[f"Q11_{m}"].mean())
        mean_list_composite_corrosion.append(df[f"Q15_{m}"].mean())

print(mean_list_composite_corrosion)

mean_corrosion_steel = sum(mean_list_steel_corrosion) / len(mean_list_steel_corrosion)
mean_corrosion_aluminium = sum(mean_list_aluminium_corrosion) / len(mean_list_aluminium_corrosion)
mean_corrosion_titanium = sum(mean_list_titanium_corrosion) / len(mean_list_titanium_corrosion)
mean_corrosion_glass = sum(mean_list_glass_corrosion) / len(mean_list_glass_corrosion)
mean_corrosion_wood = sum(mean_list_wood_corrosion) / len(mean_list_wood_corrosion)
mean_corrosion_thermoplastic = sum(mean_list_thermoplastic_corrosion) / len(mean_list_thermoplastic_corrosion)
mean_corrosion_elastomer = sum(mean_list_elastomer_corrosion) / len(mean_list_elastomer_corrosion)
mean_corrosion_thermoset = sum(mean_list_thermoset_corrosion) / len(mean_list_thermoset_corrosion)
mean_corrosion_composite = sum(mean_list_composite_corrosion) / len(mean_list_composite_corrosion)

print(mean_corrosion_composite)
# Out:
# [7.46875, 7.5625, 7.328125, 8.046875]
# 7.6015625

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_corrosion_steel, mean_corrosion_aluminium, mean_corrosion_titanium, mean_corrosion_glass, mean_corrosion_wood, mean_corrosion_thermoplastic, mean_corrosion_elastomer, mean_corrosion_thermoset, mean_corrosion_composite], marker='o', linestyle='-', color='dodgerblue')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Criterion 3: Corrosion Resistant', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %%
mean_list_steel_high_strength = []
mean_list_aluminium_high_strength = []
mean_list_titanium_high_strength = []
mean_list_glass_high_strength = []
mean_list_wood_high_strength = []
mean_list_thermoplastic_high_strength = []
mean_list_elastomer_high_strength = []
mean_list_thermoset_high_strength = []
mean_list_composite_high_strength = []

# for i in range(1, 17):
for m in materials:
    if m == "Steel":
        mean_list_steel_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_steel_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_steel_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_steel_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Aluminium":
        mean_list_aluminium_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_aluminium_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_aluminium_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_aluminium_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Titanium":
        mean_list_titanium_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_titanium_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_titanium_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_titanium_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Glass":
        mean_list_glass_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_glass_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_glass_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_glass_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Wood":
        mean_list_wood_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_wood_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_wood_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_wood_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Thermoplastic":
        mean_list_thermoplastic_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_thermoplastic_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_thermoplastic_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_thermoplastic_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Elastomer":
        mean_list_elastomer_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_elastomer_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_elastomer_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_elastomer_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Thermoset":
        mean_list_thermoset_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_thermoset_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_thermoset_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_thermoset_high_strength.append(df[f"Q16_{m}"].mean())
    elif m == "Composite":
        mean_list_composite_high_strength.append(df[f"Q4_{m}"].mean())
        mean_list_composite_high_strength.append(df[f"Q8_{m}"].mean())
        mean_list_composite_high_strength.append(df[f"Q12_{m}"].mean())
        mean_list_composite_high_strength.append(df[f"Q16_{m}"].mean())

print(mean_list_composite_high_strength)

mean_high_strength_steel = sum(mean_list_steel_high_strength) / len(mean_list_steel_high_strength)
mean_high_strength_aluminium = sum(mean_list_aluminium_high_strength) / len(mean_list_aluminium_high_strength)
mean_high_strength_titanium = sum(mean_list_titanium_high_strength) / len(mean_list_titanium_high_strength)
mean_high_strength_glass = sum(mean_list_glass_high_strength) / len(mean_list_glass_high_strength)
mean_high_strength_wood = sum(mean_list_wood_high_strength) / len(mean_list_wood_high_strength)
mean_high_strength_thermoplastic = sum(mean_list_thermoplastic_high_strength) / len(mean_list_thermoplastic_high_strength)
mean_high_strength_elastomer = sum(mean_list_elastomer_high_strength) / len(mean_list_elastomer_high_strength)
mean_high_strength_thermoset = sum(mean_list_thermoset_high_strength) / len(mean_list_thermoset_high_strength)
mean_high_strength_composite = sum(mean_list_composite_high_strength) / len(mean_list_composite_high_strength)

print(mean_high_strength_composite)
# Out:
# [6.984375, 7.546875, 6.578125, 8.390625]
# 7.375

# %%
plt.figure(figsize=(10, 8))
plt.plot(materials, [mean_high_strength_steel, mean_high_strength_aluminium, mean_high_strength_titanium, mean_high_strength_glass, mean_high_strength_wood, mean_high_strength_thermoplastic, mean_high_strength_elastomer, mean_high_strength_thermoset, mean_high_strength_composite], marker='o', linestyle='-', color='violet')

plt.xlabel('Materials', fontsize=12)
plt.title('Design Criterion 4: High Strength', fontsize=16)
plt.ylabel('Scores from Survey', fontsize=12)
plt.ylim(0, 10)

# Add value of each marker
# for i, j in zip(materials, [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]):
#     plt.text(i, j, str(j), ha='center', va='bottom')

plt.show()

# %% [markdown]
# # LLM +

# %%
import glob
import json

# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/Properties/*.json'
file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/*.json'
json_files = glob.glob(file_path)

data = []
for file in json_files:
    with open(file, 'r') as f:
        json_data = json.load(f)
        data.append(json_data)

# %%
print(len(data))
# Out:
# 16

# %%
import os

file_path = '/Users/yashpatawari/LLM-for-Material-Selection/Properties/Kitchen Utensil Grip_Corrosion Resistant_Range'  # Replace with the actual file path

file_type = os.path.splitext(file_path)[1]
print(f"The file type is: {file_type}")
# Out:
# The file type is:

# %%
import json

file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Kitchen Utensil Grip_Corrosion Resistant.json'  # Replace with the actual file path

with open(file_path) as f:
    data = json.load(f)

print(type(data))

import ast
json_1 = ast.literal_eval(data)

print(type(json_1))
# Out:
# <class 'str'>
# <class 'dict'>

# %%
import json
import ast

file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Kitchen Utensil Grip_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

case_criterion = {}

for case in design_case:
    for criterion in design_criterion:
        file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

        with open(file_path, 'r') as f:
            data = json.load(f)
            case_criterion[f"{case}_{criterion}"] = ast.literal_eval(data)

# %%
print(case_criterion['Kitchen Utensil Grip_Lightweight']['Steel'])
# Out:
# 3

# %%
material_list = {}

for m in materials:
    material_list[f"{m}"] = []

# %%
# material_list = {}
for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            material_list[f"{material}"].append(case_criterion[f"{case}_{criterion}"][f"{material}"])

# %%
print(material_list)
# Out:
# {'Steel': [3, 8, 7, 9, 3, 7, 7, 9, 3, 7, 5, 9, 2, 7, 7, 7], 'Aluminium': [8, 7, 6, 7, 8, 5, 8, 7, 8, 6, 7, 7, 7, 6, 8, 6], 'Titanium': [7, 9, 9, 8, 9, 9, 9, 10, 9, 8, 9, 10, 8, 8, 9, 8], 'Glass': [2, 5, 5, 2, 2, 3, 5, 2, 2, 5, 8, 3, 1, 2, 0, 2], 'Wood': [6, 2, 2, 6, 1, 0, 0, 0, 6, 0, 2, 1, 3, 0, 0, 3], 'Thermoplastic': [9, 1, 8, 7, 7, 2, 6, 6, 7, 4, 6, 6, 9, 5, 6, 7], 'Elastomer': [7, 1, 7, 5, 5, 1, 4, 3, 5, 3, 6, 5, 6, 4, 5, 5], 'Thermoset': [5, 3, 8, 7, 6, 4, 6, 5, 4, 5, 6, 6, 7, 7, 6, 7], 'Composite': [8, 6, 8, 8, 10, 8, 8, 8, 10, 7, 8, 8, 10, 9, 8, 9]}

# %%
average_scores = {}

for material, scores in material_list.items():
    average_scores[material] = sum(scores) / len(scores)

print(average_scores)
# Out:
# {'Steel': 6.25, 'Aluminium': 6.9375, 'Titanium': 8.6875, 'Glass': 3.0625, 'Wood': 2.0, 'Thermoplastic': 6.0, 'Elastomer': 4.5, 'Thermoset': 5.75, 'Composite': 8.3125}

# %%
import seaborn as sns

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.scatterplot(x=materials, y=[mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], marker='o', color='b')
sns.scatterplot(x=materials, y=[average_scores['Steel'], average_scores['Aluminium'], average_scores['Titanium'], average_scores['Glass'], average_scores['Wood'], average_scores['Thermoplastic'], average_scores['Elastomer'], average_scores['Thermoset'], average_scores['Composite']], marker='x', color='r')

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0, 10)

# Add legend
plt.legend(['Survey Response', 'LLM Response'])

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.scatterplot(x=[mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], y=[average_scores['Steel'], average_scores['Aluminium'], average_scores['Titanium'], average_scores['Glass'], average_scores['Wood'], average_scores['Thermoplastic'], average_scores['Elastomer'], average_scores['Thermoset'], average_scores['Composite']], marker='o', color='b')
# sns.scatterplot(x=materials, y=, marker='x', color='r')

plt.xlabel('Scores from Survey', fontsize=12)
plt.ylabel('Scores from LLM', fontsize=12)
plt.ylim(0, 10)
plt.xlim(0, 10)

# Add legend
plt.legend(materials)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 8))
sns.barplot(x=materials, y=[mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total], color='b', errorbar="sd")
sns.barplot(x=materials, y=[average_scores['Steel'], average_scores['Aluminium'], average_scores['Titanium'], average_scores['Glass'], average_scores['Wood'], average_scores['Thermoplastic'], average_scores['Elastomer'], average_scores['Thermoset'], average_scores['Composite']], color='r', errorbar="sd")

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0, 10)

# Add legend
# plt.legend(['Survey Response', 'LLM Response'])

plt.show()

# %%
survey_list = [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total]

llm_list =  [average_scores['Steel'], average_scores['Aluminium'], average_scores['Titanium'], average_scores['Glass'], average_scores['Wood'], average_scores['Thermoplastic'], average_scores['Elastomer'], average_scores['Thermoset'], average_scores['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list = sorted(llm_list)

# %%
data = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': sorted_survey_list + sorted_llm_list,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

# %%
plt.figure(figsize=(10, 6))
sns.barplot(x='Materials', y='Scores', hue='Source', data=data, errorbar="sd")
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Total Averaged out Scores by Material and Source', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()

# %% [markdown]
# STD Calculation

# %%
import numpy as np

# %%
std_scores = {}

for material, scores in material_list.items():
    std_scores[material] = np.std(scores)

print(std_scores)
# Out:
# {'Steel': 2.25, 'Aluminium': 0.899218410621135, 'Titanium': 0.7680128579652817, 'Glass': 1.9515618744994994, 'Wood': 2.179449471770337, 'Thermoplastic': 2.1213203435596424, 'Elastomer': 1.7320508075688772, 'Thermoset': 1.299038105676658, 'Composite': 1.0439558180306292}

# %%
import json
import ast

# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Kitchen Utensil Grip_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

kitchen_utensil_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if case == 'Kitchen Utensil Grip':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                kitchen_utensil_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

# %%
print(type(kitchen_utensil_llm['Kitchen Utensil Grip_Corrosion Resistant']['Steel']))
# Out:
# <class 'int'>

# %%
material_list_kitchen = {}

for m in materials:
    material_list_kitchen[f"{m}"] = []


# material_list = {}
for criterion in design_criterion:
    for material in materials:
        material_list_kitchen[f"{material}"].append(kitchen_utensil_llm[f"Kitchen Utensil Grip_{criterion}"][f"{material}"])

print(material_list_kitchen)

average_scores_kitchen = {}

for material, scores in material_list_kitchen.items():
    average_scores_kitchen[material] = sum(scores) / len(scores)

print(average_scores_kitchen)
# Out:
# {'Steel': [3, 8, 7, 9], 'Aluminium': [8, 7, 6, 7], 'Titanium': [7, 9, 9, 8], 'Glass': [2, 5, 5, 2], 'Wood': [6, 2, 2, 6], 'Thermoplastic': [9, 1, 8, 7], 'Elastomer': [7, 1, 7, 5], 'Thermoset': [5, 3, 8, 7], 'Composite': [8, 6, 8, 8]}
# {'Steel': 6.75, 'Aluminium': 7.0, 'Titanium': 8.25, 'Glass': 3.5, 'Wood': 4.0, 'Thermoplastic': 6.25, 'Elastomer': 5.0, 'Thermoset': 5.75, 'Composite': 7.5}

# %%
std_scores_kitchen = {}

for material, scores in material_list_kitchen.items():
    std_scores_kitchen[material] = np.std(scores)

print(std_scores_kitchen)
# Out:
# {'Steel': 2.277608394786075, 'Aluminium': 0.7071067811865476, 'Titanium': 0.82915619758885, 'Glass': 1.5, 'Wood': 2.0, 'Thermoplastic': 3.112474899497183, 'Elastomer': 2.449489742783178, 'Thermoset': 1.920286436967152, 'Composite': 0.8660254037844386}

# %%
std_list_kitchen = []
for m in materials:
    std_list_kitchen.append(std_scores_kitchen[m])

print(std_list_kitchen)
# Out:
# [2.277608394786075, 0.7071067811865476, 0.82915619758885, 1.5, 2.0, 3.112474899497183, 2.449489742783178, 1.920286436967152, 0.8660254037844386]

# %%
survey_list_kitchen = [mean_kitchen_steel, mean_kitchen_aluminium, mean_kitchen_titanium, mean_kitchen_glass, mean_kitchen_wood, mean_kitchen_thermoplastic, mean_kitchen_elastomer, mean_kitchen_thermoset, mean_kitchen_composite]

llm_list_kitchen =  [average_scores_kitchen['Steel'], average_scores_kitchen['Aluminium'], average_scores_kitchen['Titanium'], average_scores_kitchen['Glass'], average_scores_kitchen['Wood'], average_scores_kitchen['Thermoplastic'], average_scores_kitchen['Elastomer'], average_scores_kitchen['Thermoset'], average_scores_kitchen['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_kitchen = sorted(llm_list_kitchen)


data_kitchen = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_kitchen + llm_list_kitchen,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials),
    # 'Error': [std if source == 'from_Survey' else None for source, std in zip(['from_Survey'] * len(materials), std_list_kitchen)]
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_kitchen, yerr=std_list_kitchen[:len(materials)], palette=color_palette)
# sns.barplot(x='Materials', y='Scores', hue='Source', data=data_kitchen, palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Case 1 (Kitchen Utensil Grip): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()

# %% [markdown]
# ## Spacecraft Component

# %%
import json
import ast

# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Spacecraft Component_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

spacecraft_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if case == 'Spacecraft Component':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                spacecraft_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_spacecraft = {}

for m in materials:
    material_list_spacecraft[f"{m}"] = []


# material_list = {}
for criterion in design_criterion:
    for material in materials:
        material_list_spacecraft[f"{material}"].append(spacecraft_llm[f"Spacecraft Component_{criterion}"][f"{material}"])

print(material_list_spacecraft)

average_scores_spacecraft = {}

for material, scores in material_list_spacecraft.items():
    average_scores_spacecraft[material] = sum(scores) / len(scores)

print(average_scores_spacecraft)

std_scores_spacecraft = {}

for material, scores in material_list_spacecraft.items():
    std_scores_spacecraft[material] = np.std(scores)
    

print(std_scores_spacecraft)

std_list_spacecraft = []
for m in materials:
    std_list_spacecraft.append(std_scores_spacecraft[m])
    # std_list_spacecraft.append(0)

print(std_list_spacecraft)

survey_list_spacecraft = [mean_spacecraft_steel, mean_spacecraft_aluminium, mean_spacecraft_titanium, mean_spacecraft_glass, mean_spacecraft_wood, mean_spacecraft_thermoplastic, mean_spacecraft_elastomer, mean_spacecraft_thermoset, mean_spacecraft_composite]

llm_list_spacecraft =  [average_scores_spacecraft['Steel'], average_scores_spacecraft['Aluminium'], average_scores_spacecraft['Titanium'], average_scores_spacecraft['Glass'], average_scores_spacecraft['Wood'], average_scores_spacecraft['Thermoplastic'], average_scores_spacecraft['Elastomer'], average_scores_spacecraft['Thermoset'], average_scores_spacecraft['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_spacecraft = sorted(llm_list_spacecraft)


data_spacecraft = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_spacecraft + llm_list_spacecraft,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft, yerr=std_list_spacecraft[:len(materials)], palette=color_palette)
# sns.barplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft, yerr=std_list_spacecraft[:len(materials)], palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Case 2 (Spacecraft Component): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [3, 7, 7, 9], 'Aluminium': [8, 5, 8, 7], 'Titanium': [9, 9, 9, 10], 'Glass': [2, 3, 5, 2], 'Wood': [1, 0, 0, 0], 'Thermoplastic': [7, 2, 6, 6], 'Elastomer': [5, 1, 4, 3], 'Thermoset': [6, 4, 6, 5], 'Composite': [10, 8, 8, 8]}
# {'Steel': 6.5, 'Aluminium': 7.0, 'Titanium': 9.25, 'Glass': 3.0, 'Wood': 0.25, 'Thermoplastic': 5.25, 'Elastomer': 3.25, 'Thermoset': 5.25, 'Composite': 8.5}
# {'Steel': 2.179449471770337, 'Aluminium': 1.224744871391589, 'Titanium': 0.4330127018922193, 'Glass': 1.224744871391589, 'Wood': 0.4330127018922193, 'Thermoplastic': 1.920286436967152, 'Elastomer': 1.479019945774904, 'Thermoset': 0.82915619758885, 'Composite': 0.8660254037844386}
# [2.179449471770337, 1.224744871391589, 0.4330127018922193, 1.224744871391589, 0.4330127018922193, 1.920286436967152, 1.479019945774904, 0.82915619758885, 0.8660254037844386]

# %% [markdown]
# replace everything in this code such that Kitchen Utensil Grip is replaced by Spacecraft Component. Even all variables.

# %%
import ast

# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Underwater Component_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

underwater_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if case == 'Underwater Component':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                underwater_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_underwater = {}

for m in materials:
    material_list_underwater[f"{m}"] = []


# material_list = {}
for criterion in design_criterion:
    for material in materials:
        material_list_underwater[f"{material}"].append(underwater_llm[f"Underwater Component_{criterion}"][f"{material}"])

print(material_list_underwater)

average_scores_underwater = {}

for material, scores in material_list_underwater.items():
    average_scores_underwater[material] = sum(scores) / len(scores)

print(average_scores_underwater)

survey_list_underwater = [mean_underwater_steel, mean_underwater_aluminium, mean_underwater_titanium, mean_underwater_glass, mean_underwater_wood, mean_underwater_thermoplastic, mean_underwater_elastomer, mean_underwater_thermoset, mean_underwater_composite]

llm_list_underwater =  [average_scores_underwater['Steel'], average_scores_underwater['Aluminium'], average_scores_underwater['Titanium'], average_scores_underwater['Glass'], average_scores_underwater['Wood'], average_scores_underwater['Thermoplastic'], average_scores_underwater['Elastomer'], average_scores_underwater['Thermoset'], average_scores_underwater['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_underwater = sorted(llm_list_underwater)


data_underwater = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_underwater + llm_list_underwater,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_underwater, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Case 3 (Underwater Component): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [3, 7, 5, 9], 'Aluminium': [8, 6, 7, 7], 'Titanium': [9, 8, 9, 10], 'Glass': [2, 5, 8, 3], 'Wood': [6, 0, 2, 1], 'Thermoplastic': [7, 4, 6, 6], 'Elastomer': [5, 3, 6, 5], 'Thermoset': [4, 5, 6, 6], 'Composite': [10, 7, 8, 8]}
# {'Steel': 6.0, 'Aluminium': 7.0, 'Titanium': 9.0, 'Glass': 4.5, 'Wood': 2.25, 'Thermoplastic': 5.75, 'Elastomer': 4.75, 'Thermoset': 5.25, 'Composite': 8.25}

# %%
import seaborn as sns
# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Safety Helmet_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

safety_helmet_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if case == 'Safety Helmet':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                safety_helmet_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_safety_helmet = {}

for m in materials:
    material_list_safety_helmet[f"{m}"] = []


# material_list = {}
for criterion in design_criterion:
    for material in materials:
        material_list_safety_helmet[f"{material}"].append(safety_helmet_llm[f"Safety Helmet_{criterion}"][f"{material}"])

print(material_list_safety_helmet)

average_scores_safety_helmet = {}

for material, scores in material_list_safety_helmet.items():
    average_scores_safety_helmet[material] = sum(scores) / len(scores)

print(average_scores_safety_helmet)

survey_list_safety_helmet = [mean_helmet_steel, mean_helmet_aluminium, mean_helmet_titanium, mean_helmet_glass, mean_helmet_wood, mean_helmet_thermoplastic, mean_helmet_elastomer, mean_helmet_thermoset, mean_helmet_composite]

llm_list_safety_helmet =  [average_scores_safety_helmet['Steel'], average_scores_safety_helmet['Aluminium'], average_scores_safety_helmet['Titanium'], average_scores_safety_helmet['Glass'], average_scores_safety_helmet['Wood'], average_scores_safety_helmet['Thermoplastic'], average_scores_safety_helmet['Elastomer'], average_scores_safety_helmet['Thermoset'], average_scores_safety_helmet['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_safety_helmet = sorted(llm_list_safety_helmet)


data_safety_helmet = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_safety_helmet + llm_list_safety_helmet,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
# sns.barplot(x='Materials', y='Scores', hue='Source', data=data_safety_helmet, errorbar="sd")
# Define a color palette
# Import the colorblind-friendly palette from seaborn
# Define the colorblind-friendly palette
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_safety_helmet, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Case 4 (Safety Helmet): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()

# # Plot the bar chart with the specified color palette
# sns.barplot(x='Materials', y='Scores', hue='Source', data=data_safety_helmet, errorbar="sd", palette=colors)
# plt.xlabel('Materials', fontsize=12)
# plt.ylabel('Scores', fontsize=12)
# plt.title('Design Case 4 (Safety Helmet): Total Averaged out Scores', fontsize=16)
# plt.xticks(rotation=45, ha='right')
# plt.legend(title='Source')
# plt.show()
# Out:
# {'Steel': [2, 7, 7, 7], 'Aluminium': [7, 6, 8, 6], 'Titanium': [8, 8, 9, 8], 'Glass': [1, 2, 0, 2], 'Wood': [3, 0, 0, 3], 'Thermoplastic': [9, 5, 6, 7], 'Elastomer': [6, 4, 5, 5], 'Thermoset': [7, 7, 6, 7], 'Composite': [10, 9, 8, 9]}
# {'Steel': 5.75, 'Aluminium': 6.75, 'Titanium': 8.25, 'Glass': 1.25, 'Wood': 1.5, 'Thermoplastic': 6.75, 'Elastomer': 5.0, 'Thermoset': 6.75, 'Composite': 9.0}

# %% [markdown]
# # Criterion
#
# ## Lightweight

# %%
# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Safety Helmet_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

lightweight_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'Lightweight':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                lightweight_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_lightweight = {}

for m in materials:
    material_list_lightweight[f"{m}"] = []


# material_list = {}
for case in design_case:
    for material in materials:
        material_list_lightweight[f"{material}"].append(lightweight_llm[f"{case}_Lightweight"][f"{material}"])

print(material_list_lightweight)

average_scores_lightweight = {}

for material, scores in material_list_lightweight.items():
    average_scores_lightweight[material] = sum(scores) / len(scores)

print(average_scores_lightweight)

survey_list_lightweight = [mean_lightweight_steel, mean_lightweight_aluminium, mean_lightweight_titanium, mean_lightweight_glass, mean_lightweight_wood, mean_lightweight_thermoplastic, mean_lightweight_elastomer, mean_lightweight_thermoset, mean_lightweight_composite]

llm_list_lightweight =  [average_scores_lightweight['Steel'], average_scores_lightweight['Aluminium'], average_scores_lightweight['Titanium'], average_scores_lightweight['Glass'], average_scores_lightweight['Wood'], average_scores_lightweight['Thermoplastic'], average_scores_lightweight['Elastomer'], average_scores_lightweight['Thermoset'], average_scores_lightweight['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_lightweight = sorted(llm_list_safety_helmet)


data_lightweight = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_lightweight + llm_list_lightweight,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_lightweight, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Criterion 1 (Lightweight): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [3, 3, 3, 2], 'Aluminium': [8, 8, 8, 7], 'Titanium': [7, 9, 9, 8], 'Glass': [2, 2, 2, 1], 'Wood': [6, 6, 1, 3], 'Thermoplastic': [9, 7, 7, 9], 'Elastomer': [7, 5, 5, 6], 'Thermoset': [5, 4, 6, 7], 'Composite': [8, 10, 10, 10]}
# {'Steel': 2.75, 'Aluminium': 7.75, 'Titanium': 8.25, 'Glass': 1.75, 'Wood': 4.0, 'Thermoplastic': 8.0, 'Elastomer': 5.75, 'Thermoset': 5.5, 'Composite': 9.5}

# %% [markdown]
# # Resistant to Heat

# %% [markdown]
# replace everything in this code such that Kitchen Utensil Grip is replaced by Spacecraft Component. Even all variables.

# %%
design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

resistant_to_heat_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'Resistant to Heat':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                resistant_to_heat_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_resistant_to_heat = {}

for m in materials:
    material_list_resistant_to_heat[f"{m}"] = []


# material_list = {}
for case in design_case:
    for material in materials:
        material_list_resistant_to_heat[f"{material}"].append(resistant_to_heat_llm[f"{case}_Resistant to Heat"][f"{material}"])

print(material_list_resistant_to_heat)

average_scores_resistant_to_heat = {}

for material, scores in material_list_resistant_to_heat.items():
    average_scores_resistant_to_heat[material] = sum(scores) / len(scores)

print(average_scores_resistant_to_heat)

survey_list_rest_to_heat = [mean_rest_to_heat_steel, mean_rest_to_heat_aluminium, mean_rest_to_heat_titanium, mean_rest_to_heat_glass, mean_rest_to_heat_wood, mean_rest_to_heat_thermoplastic, mean_rest_to_heat_elastomer, mean_rest_to_heat_thermoset, mean_rest_to_heat_composite]

llm_list_resistant_to_heat =  [average_scores_resistant_to_heat['Steel'], average_scores_resistant_to_heat['Aluminium'], average_scores_resistant_to_heat['Titanium'], average_scores_resistant_to_heat['Glass'], average_scores_resistant_to_heat['Wood'], average_scores_resistant_to_heat['Thermoplastic'], average_scores_resistant_to_heat['Elastomer'], average_scores_resistant_to_heat['Thermoset'], average_scores_resistant_to_heat['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_resistant_to_heat = sorted(llm_list_resistant_to_heat)


data_resistant_to_heat = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_rest_to_heat + llm_list_resistant_to_heat,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_resistant_to_heat, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Criterion 2 (Resistant to Heat): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [8, 7, 7, 7], 'Aluminium': [7, 6, 5, 6], 'Titanium': [9, 8, 9, 8], 'Glass': [5, 5, 3, 2], 'Wood': [2, 0, 0, 0], 'Thermoplastic': [1, 4, 2, 5], 'Elastomer': [1, 3, 1, 4], 'Thermoset': [3, 5, 4, 7], 'Composite': [6, 7, 8, 9]}
# {'Steel': 7.25, 'Aluminium': 6.0, 'Titanium': 8.5, 'Glass': 3.75, 'Wood': 0.5, 'Thermoplastic': 3.0, 'Elastomer': 2.25, 'Thermoset': 4.75, 'Composite': 7.5}

# %% [markdown]
# # Corrosion Resistant

# %% [markdown]
# replace everything in this code such that Lightweight is replaced by Resistant to Heat. Even all variables.

# %%
design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

corrosion_resistant_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'Corrosion Resistant':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                corrosion_resistant_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_corrosion_resistant = {}

for m in materials:
    material_list_corrosion_resistant[f"{m}"] = []


# material_list = {}
for case in design_case:
    for material in materials:
        material_list_corrosion_resistant[f"{material}"].append(corrosion_resistant_llm[f"{case}_Corrosion Resistant"][f"{material}"])

print(material_list_corrosion_resistant)

average_scores_corrosion_resistant = {}

for material, scores in material_list_corrosion_resistant.items():
    average_scores_corrosion_resistant[material] = sum(scores) / len(scores)

print(average_scores_corrosion_resistant)

survey_list_corrosion = [mean_corrosion_steel, mean_corrosion_aluminium, mean_corrosion_titanium, mean_corrosion_glass, mean_corrosion_wood, mean_corrosion_thermoplastic, mean_corrosion_elastomer, mean_corrosion_thermoset, mean_corrosion_composite]

llm_list_corrosion_resistant =  [average_scores_corrosion_resistant['Steel'], average_scores_corrosion_resistant['Aluminium'], average_scores_corrosion_resistant['Titanium'], average_scores_corrosion_resistant['Glass'], average_scores_corrosion_resistant['Wood'], average_scores_corrosion_resistant['Thermoplastic'], average_scores_corrosion_resistant['Elastomer'], average_scores_corrosion_resistant['Thermoset'], average_scores_corrosion_resistant['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_corrosion_resistant = sorted(llm_list_corrosion_resistant)


data_corrosion_resistant = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_corrosion + llm_list_corrosion_resistant,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_corrosion_resistant, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.title('Design Criterion 3 (Corrosion Resistance): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [7, 5, 7, 7], 'Aluminium': [6, 7, 8, 8], 'Titanium': [9, 9, 9, 9], 'Glass': [5, 8, 5, 0], 'Wood': [2, 2, 0, 0], 'Thermoplastic': [8, 6, 6, 6], 'Elastomer': [7, 6, 4, 5], 'Thermoset': [8, 6, 6, 6], 'Composite': [8, 8, 8, 8]}
# {'Steel': 6.5, 'Aluminium': 7.25, 'Titanium': 9.0, 'Glass': 4.5, 'Wood': 1.0, 'Thermoplastic': 6.5, 'Elastomer': 5.5, 'Thermoset': 6.5, 'Composite': 8.0}

# %% [markdown]
# # High Strength

# %%
design_case = ['Kitchen Utensil Grip', 'Underwater Component', 'Spacecraft Component', 'Safety Helmet'] 
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

high_strength_llm = {}

for case in design_case: 
    for criterion in design_criterion: 
        if criterion == 'High Strength': 
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json' 
            # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}{criterion}.json')
            with open(file_path, 'r') as f:
                data = json.load(f)
                high_strength_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_high_strength = {}

for m in materials: 
    material_list_high_strength[f"{m}"] = []

material_list = {}
for case in design_case: 
    for material in materials: 
        material_list_high_strength[f"{material}"].append(high_strength_llm[f"{case}_High Strength"][f"{material}"])

print(material_list_high_strength)

average_scores_high_strength = {}

for material, scores in material_list_high_strength.items(): 
    average_scores_high_strength[material] = sum(scores) / len(scores)

print(average_scores_high_strength)

survey_list_high_strength = [mean_high_strength_steel, mean_high_strength_aluminium, mean_high_strength_titanium, mean_high_strength_glass, mean_high_strength_wood, mean_high_strength_thermoplastic, mean_high_strength_elastomer, mean_high_strength_thermoset, mean_high_strength_composite]

llm_list_high_strength = [average_scores_high_strength['Steel'], average_scores_high_strength['Aluminium'], average_scores_high_strength['Titanium'], average_scores_high_strength['Glass'], average_scores_high_strength['Wood'], average_scores_high_strength['Thermoplastic'], average_scores_high_strength['Elastomer'], average_scores_high_strength['Thermoset'], average_scores_high_strength['Composite']]

sorted_survey_list = sorted(survey_list) 
sorted_llm_list_high_strength = sorted(llm_list_high_strength)

data_high_strength = pd.DataFrame({ 'Materials': materials * 2, 'Scores': survey_list_high_strength + llm_list_high_strength, 'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials) })

plt.figure(figsize=(10, 6)) 
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_high_strength, errorbar="sd", palette=color_palette)
plt.xlabel('Materials', fontsize=12) 
plt.ylabel('Scores', fontsize=12) 
plt.title('Design Criterion 4 (High Strength): Total Averaged out Scores', fontsize=16) 
plt.xticks(rotation=45, ha='right') 
plt.legend(title='Source') 
plt.show()
# Out:
# {'Steel': [9, 9, 9, 7], 'Aluminium': [7, 7, 7, 6], 'Titanium': [8, 10, 10, 8], 'Glass': [2, 3, 2, 2], 'Wood': [6, 1, 0, 3], 'Thermoplastic': [7, 6, 6, 7], 'Elastomer': [5, 5, 3, 5], 'Thermoset': [7, 6, 5, 7], 'Composite': [8, 8, 8, 9]}
# {'Steel': 8.5, 'Aluminium': 6.75, 'Titanium': 9.0, 'Glass': 2.25, 'Wood': 2.5, 'Thermoplastic': 6.5, 'Elastomer': 4.5, 'Thermoset': 6.25, 'Composite': 8.25}

# %% [markdown]
# ## Change to Scatter + Bar

# %%
import json
import ast
import numpy as np

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

total_llm = {}

for case in design_case:
    for criterion in design_criterion:
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

            with open(file_path, 'r') as f:
                data = json.load(f)
                total_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_total = {}

for m in materials:
    material_list_total[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            material_list_total[f"{material}"].append(total_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_total)




average_scores_total = {}

for material, scores in material_list_total.items():
    average_scores_total[material] = sum(scores) / len(scores)

print(average_scores_total)

std_scores_total = {}

for material, scores in material_list_total.items():
    std_scores_total[material] = np.std(scores)
    

print(std_scores_total)

std_list_total = []
for m in materials:
    std_list_total.append(std_scores_total[m])

print("Standard Deviation Survey",std_list_total)

survey_total_means = [mean_steel_total, mean_aluminium_total, mean_titanium_total, mean_glass_total, mean_wood_total, mean_thermoplastic_total, mean_elastomer_total, mean_thermoset_total, mean_composite_total]

llm_list_total =  [average_scores_total['Steel'], average_scores_total['Aluminium'], average_scores_total['Titanium'], average_scores_total['Glass'], average_scores_total['Wood'], average_scores_total['Thermoplastic'], average_scores_total['Elastomer'], average_scores_total['Thermoset'], average_scores_total['Composite']]


print("Material List Means: ", llm_list_total)

print("Survey List Mean: ", survey_total_means)


data_total = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_total_means + llm_list_total,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_total[:len(materials)], palette=color_palette, yerr=std_list_total[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_total[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('LLM vs Survey (All Responses): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# {'Steel': [3, 8, 7, 9, 3, 7, 7, 9, 3, 7, 5, 9, 2, 7, 7, 7], 'Aluminium': [8, 7, 6, 7, 8, 5, 8, 7, 8, 6, 7, 7, 7, 6, 8, 6], 'Titanium': [7, 9, 9, 8, 9, 9, 9, 10, 9, 8, 9, 10, 8, 8, 9, 8], 'Glass': [2, 5, 5, 2, 2, 3, 5, 2, 2, 5, 8, 3, 1, 2, 0, 2], 'Wood': [6, 2, 2, 6, 1, 0, 0, 0, 6, 0, 2, 1, 3, 0, 0, 3], 'Thermoplastic': [9, 1, 8, 7, 7, 2, 6, 6, 7, 4, 6, 6, 9, 5, 6, 7], 'Elastomer': [7, 1, 7, 5, 5, 1, 4, 3, 5, 3, 6, 5, 6, 4, 5, 5], 'Thermoset': [5, 3, 8, 7, 6, 4, 6, 5, 4, 5, 6, 6, 7, 7, 6, 7], 'Composite': [8, 6, 8, 8, 10, 8, 8, 8, 10, 7, 8, 8, 10, 9, 8, 9]}
# {'Steel': 6.25, 'Aluminium': 6.9375, 'Titanium': 8.6875, 'Glass': 3.0625, 'Wood': 2.0, 'Thermoplastic': 6.0, 'Elastomer': 4.5, 'Thermoset': 5.75, 'Composite': 8.3125}
# ...

# %%
import json
import ast
import numpy as np

# file_path = '/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Spacecraft Component_Corrosion Resistant.json'  # Replace with the actual file path

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

spacecraft_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if case == 'Spacecraft Component':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        # file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'

            with open(file_path, 'r') as f:
                data = json.load(f)
                spacecraft_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_spacecraft = {}

for m in materials:
    material_list_spacecraft[f"{m}"] = []

# print("Material List Means: ",material_list_spacecraft)


# material_list = {}
for criterion in design_criterion:
    for material in materials:
        material_list_spacecraft[f"{material}"].append(spacecraft_llm[f"Spacecraft Component_{criterion}"][f"{material}"])

print(material_list_spacecraft)
# print("Material List Means: ",material_list_spacecraft)



average_scores_spacecraft = {}

for material, scores in material_list_spacecraft.items():
    average_scores_spacecraft[material] = sum(scores) / len(scores)

print(average_scores_spacecraft)

std_scores_spacecraft = {}

for material, scores in material_list_spacecraft.items():
    std_scores_spacecraft[material] = np.std(scores)
    

print(std_scores_spacecraft)

std_list_spacecraft = []
for m in materials:
    std_list_spacecraft.append(std_scores_spacecraft[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_spacecraft)

survey_list_steel = [mean_spacecraft_steel, mean_spacecraft_aluminium, mean_spacecraft_titanium, mean_spacecraft_glass, mean_spacecraft_wood, mean_spacecraft_thermoplastic, mean_spacecraft_elastomer, mean_spacecraft_thermoset, mean_spacecraft_composite]

llm_list_spacecraft =  [average_scores_spacecraft['Steel'], average_scores_spacecraft['Aluminium'], average_scores_spacecraft['Titanium'], average_scores_spacecraft['Glass'], average_scores_spacecraft['Wood'], average_scores_spacecraft['Thermoplastic'], average_scores_spacecraft['Elastomer'], average_scores_spacecraft['Thermoset'], average_scores_spacecraft['Composite']]

sorted_survey_list = sorted(survey_list)
sorted_llm_list_spacecraft = sorted(llm_list_spacecraft)

print("Material List Means: ", llm_list_spacecraft)

print("Survey List Mean: ", survey_list)


data_spacecraft = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_steel + llm_list_spacecraft,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[:len(materials)], palette=color_palette, yerr=std_list_spacecraft[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Case 2 (Spacecraft Component): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': [3, 7, 7, 9], 'Aluminium': [8, 5, 8, 7], 'Titanium': [9, 9, 9, 10], 'Glass': [2, 3, 5, 2], 'Wood': [1, 0, 0, 0], 'Thermoplastic': [7, 2, 6, 6], 'Elastomer': [5, 1, 4, 3], 'Thermoset': [6, 4, 6, 5], 'Composite': [10, 8, 8, 8]}
# {'Steel': 6.5, 'Aluminium': 7.0, 'Titanium': 9.25, 'Glass': 3.0, 'Wood': 0.25, 'Thermoplastic': 5.25, 'Elastomer': 3.25, 'Thermoset': 5.25, 'Composite': 8.5}
# {'Steel': 2.179449471770337, 'Aluminium': 1.224744871391589, 'Titanium': 0.4330127018922193, 'Glass': 1.224744871391589, 'Wood': 0.4330127018922193, 'Thermoplastic': 1.920286436967152, 'Elastomer': 1.479019945774904, 'Thermoset': 0.82915619758885, 'Composite': 0.8660254037844386}
# Standard Deviation Survey [2.179449471770337, 1.224744871391589, 0.4330127018922193, 1.224744871391589, 0.4330127018922193, 1.920286436967152, 1.479019945774904, 0.82915619758885, 0.8660254037844386]
# Material List Means:  [6.5, 7.0, 9.25, 3.0, 0.25, 5.25, 3.25, 5.25, 8.5]
# ...

# %%
std_scores_kitchen = {}

for material, scores in material_list_kitchen.items():
    std_scores_kitchen[material] = np.std(scores)
    

print(std_scores_kitchen)

std_list_kitchen = []
for m in materials:
    std_list_kitchen.append(std_scores_kitchen[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_kitchen)

data_kitchen = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_kitchen + llm_list_kitchen,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_kitchen[:len(materials)], palette=color_palette, yerr=std_list_kitchen[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_kitchen[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Case 1 (Kitchen Utensil Grip): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 2.277608394786075, 'Aluminium': 0.7071067811865476, 'Titanium': 0.82915619758885, 'Glass': 1.5, 'Wood': 2.0, 'Thermoplastic': 3.112474899497183, 'Elastomer': 2.449489742783178, 'Thermoset': 1.920286436967152, 'Composite': 0.8660254037844386}
# Standard Deviation Survey [2.277608394786075, 0.7071067811865476, 0.82915619758885, 1.5, 2.0, 3.112474899497183, 2.449489742783178, 1.920286436967152, 0.8660254037844386]

# %%
std_scores_underwater = {}

for material, scores in material_list_underwater.items():
    std_scores_underwater[material] = np.std(scores)
    

print(std_scores_underwater)

std_list_underwater = []
for m in materials:
    std_list_underwater.append(std_scores_underwater[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_underwater)

data_underwater = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_underwater + llm_list_underwater,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_underwater[:len(materials)], palette=color_palette, yerr=std_list_underwater[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_underwater[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Case 3 (Underwater Component): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 2.23606797749979, 'Aluminium': 0.7071067811865476, 'Titanium': 0.7071067811865476, 'Glass': 2.29128784747792, 'Wood': 2.277608394786075, 'Thermoplastic': 1.0897247358851685, 'Elastomer': 1.0897247358851685, 'Thermoset': 0.82915619758885, 'Composite': 1.0897247358851685}
# Standard Deviation Survey [2.23606797749979, 0.7071067811865476, 0.7071067811865476, 2.29128784747792, 2.277608394786075, 1.0897247358851685, 1.0897247358851685, 0.82915619758885, 1.0897247358851685]

# %%
std_scores_safety_helmet = {}

for material, scores in material_list_safety_helmet.items():
    std_scores_safety_helmet[material] = np.std(scores)
    

print(std_scores_safety_helmet)

std_list_safety_helmet = []
for m in materials:
    std_list_safety_helmet.append(std_scores_safety_helmet[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_safety_helmet)

data_safety_helmet = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_safety_helmet + llm_list_safety_helmet,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_safety_helmet[:len(materials)], palette=color_palette, yerr=std_list_safety_helmet[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_safety_helmet[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Case 4 (Safety Helmet): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 2.165063509461097, 'Aluminium': 0.82915619758885, 'Titanium': 0.4330127018922193, 'Glass': 0.82915619758885, 'Wood': 1.5, 'Thermoplastic': 1.479019945774904, 'Elastomer': 0.7071067811865476, 'Thermoset': 0.4330127018922193, 'Composite': 0.7071067811865476}
# Standard Deviation Survey [2.165063509461097, 0.82915619758885, 0.4330127018922193, 0.82915619758885, 1.5, 1.479019945774904, 0.7071067811865476, 0.4330127018922193, 0.7071067811865476]

# %% [markdown]
# # Criterion

# %%
std_scores_lightweight = {}

for material, scores in material_list_lightweight.items():
    std_scores_lightweight[material] = np.std(scores)
    

print(std_scores_lightweight)

std_list_lightweight = []
for m in materials:
    std_list_lightweight.append(std_scores_lightweight[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_lightweight)

data_lightweight = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_lightweight + llm_list_lightweight,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_lightweight[:len(materials)], palette=color_palette, yerr=std_list_lightweight[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_lightweight[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Criterion 1 (Lightweight): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 0.4330127018922193, 'Aluminium': 0.4330127018922193, 'Titanium': 0.82915619758885, 'Glass': 0.4330127018922193, 'Wood': 2.1213203435596424, 'Thermoplastic': 1.0, 'Elastomer': 0.82915619758885, 'Thermoset': 1.118033988749895, 'Composite': 0.8660254037844386}
# Standard Deviation Survey [0.4330127018922193, 0.4330127018922193, 0.82915619758885, 0.4330127018922193, 2.1213203435596424, 1.0, 0.82915619758885, 1.118033988749895, 0.8660254037844386]

# %%
std_scores_rest_to_heat = {}

for material, scores in material_list_resistant_to_heat.items():
    std_scores_rest_to_heat[material] = np.std(scores)
    

print(std_scores_rest_to_heat)

std_list_rest_to_heat = []
for m in materials:
    std_list_rest_to_heat.append(std_scores_rest_to_heat[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_rest_to_heat)

data_rest_to_heat = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_rest_to_heat + llm_list_resistant_to_heat,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_rest_to_heat[:len(materials)], palette=color_palette, yerr=std_list_rest_to_heat[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_rest_to_heat[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Criterion 2 (Resistant to Heat): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 0.4330127018922193, 'Aluminium': 0.7071067811865476, 'Titanium': 0.5, 'Glass': 1.299038105676658, 'Wood': 0.8660254037844386, 'Thermoplastic': 1.5811388300841898, 'Elastomer': 1.299038105676658, 'Thermoset': 1.479019945774904, 'Composite': 1.118033988749895}
# Standard Deviation Survey [0.4330127018922193, 0.7071067811865476, 0.5, 1.299038105676658, 0.8660254037844386, 1.5811388300841898, 1.299038105676658, 1.479019945774904, 1.118033988749895]

# %%
std_scores_corrosion = {}

for material, scores in material_list_corrosion_resistant.items():
    std_scores_corrosion[material] = np.std(scores)
    

print(std_scores_corrosion)

std_list_corrosion = []
for m in materials:
    std_list_corrosion.append(std_scores_corrosion[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_corrosion)

data_corrosion = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_corrosion + llm_list_corrosion_resistant,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_corrosion[:len(materials)], palette=color_palette, yerr=std_list_corrosion[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_corrosion[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Criterion 3 (Corrosion Resistant): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 0.8660254037844386, 'Aluminium': 0.82915619758885, 'Titanium': 0.0, 'Glass': 2.8722813232690143, 'Wood': 1.0, 'Thermoplastic': 0.8660254037844386, 'Elastomer': 1.118033988749895, 'Thermoset': 0.8660254037844386, 'Composite': 0.0}
# Standard Deviation Survey [0.8660254037844386, 0.82915619758885, 0.0, 2.8722813232690143, 1.0, 0.8660254037844386, 1.118033988749895, 0.8660254037844386, 0.0]

# %%
std_scores_high_strength = {}

for material, scores in material_list_high_strength.items():
    std_scores_high_strength[material] = np.std(scores)
    

print(std_scores_high_strength)

std_list_high_strength = []
for m in materials:
    std_list_high_strength.append(std_scores_high_strength[m])
    # std_list_spacecraft.append(0)

print("Standard Deviation Survey",std_list_high_strength)

data_high_strength = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_high_strength + llm_list_high_strength,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_high_strength[:len(materials)], palette=color_palette, yerr=std_list_high_strength[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_high_strength[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Criterion 4 (High Strength): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_spacecraft[len(materials):], palette="r", s=100)
# Out:
# {'Steel': 0.8660254037844386, 'Aluminium': 0.4330127018922193, 'Titanium': 1.0, 'Glass': 0.4330127018922193, 'Wood': 2.29128784747792, 'Thermoplastic': 0.5, 'Elastomer': 0.8660254037844386, 'Thermoset': 0.82915619758885, 'Composite': 0.4330127018922193}
# Standard Deviation Survey [0.8660254037844386, 0.4330127018922193, 1.0, 0.4330127018922193, 2.29128784747792, 0.5, 0.8660254037844386, 0.82915619758885, 0.4330127018922193]

# %% [markdown]
# # Box and Whisker Plot

# %%
import matplotlib.pyplot as plt

# Calculate relevant details from survey data
survey_data = [data_total['Scores'], data_lightweight['Scores'], data_resistant_to_heat['Scores'], data_corrosion_resistant['Scores'], data_high_strength['Scores']]
print(survey_data)
survey_labels = ['Total', 'Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

# Plot box and whisker plot
fig, ax = plt.subplots()
ax.boxplot(survey_data, labels=survey_labels)

# Plot LLM data as points
llm_data = [average_scores_total['Composite'], average_scores_lightweight['Composite'], average_scores_resistant_to_heat['Composite'], average_scores_corrosion_resistant['Composite'], average_scores_high_strength['Composite']]
llm_labels = ['Total (LLM)', 'Lightweight (LLM)', 'Resistant to Heat (LLM)', 'Corrosion Resistant (LLM)', 'High Strength (LLM)']
ax.plot(range(1, len(llm_data) + 1), llm_data, 'ro', label='LLM')
ax.set_xticklabels(llm_labels, rotation=45)

# Set plot title and labels
ax.set_title('Box and Whisker Plot')
ax.set_xlabel('Design Criterion')
ax.set_ylabel('Scores')

# Show legend
ax.legend()

# Show the plot
plt.show()
# Out:
# [0     4.636719
# 1     5.934570
# 2     6.990234
# 3     3.423828
# 4     3.144531
# 5     4.708008
# 6     3.694336
# 7     4.705078
# 8     7.208984
# 9     6.250000
# 10    6.937500
# 11    8.687500
# 12    3.062500
# 13    2.000000
# 14    6.000000
# 15    4.500000
# 16    5.750000
# 17    8.312500
# Name: Scores, dtype: float64, 0     3.050781
# 1     6.179688
# 2     6.140625
# 3     2.132812
# 4     3.285156
# 5     5.117188
# 6     3.992188
# 7     4.742188
# 8     7.722656
# 9     2.750000
# 10    7.750000
# 11    8.250000
# 12    1.750000
# 13    4.000000
# 14    8.000000
# 15    5.750000
# 16    5.500000
# 17    9.500000
# Name: Scores, dtype: float64, 0     5.132812
# 1     5.042969
# 2     6.484375
# 3     3.914062
# 4     2.894531
# 5     3.582031
# 6     2.988281
# 7     4.191406
# 8     6.136719
# 9     7.250000
# 10    6.000000
# 11    8.500000
# 12    3.750000
# 13    0.500000
# 14    3.000000
# 15    2.250000
# 16    4.750000
# 17    7.500000
# ...

# %% [markdown]
# # TOTAL FROM LLM AND SURVEY

# %%
materials = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']


list_material_total = {}
for material in materials:
    list_material_total[material] = []
    for i in range(1, 17):
        list_material_total[material].extend(df[f"Q{i}_{material}"])


print(list_material_total['Steel'])
print(len(list_material_total['Steel']))
# Out:
# [0, 7, 7, 2, 5, 6, 3, 6, 0, 0, 1, 3, 3, 5, 1, 3, 1, 1, 5, 0, 1, 2, 2, 5, 0, 5, 3, 1, 4, 6, 3, 4, 0, 6, 2, 2, 3, 5, 3, 0, 6, 0, 5, 1, 0, 5, 5, 1, 5, 3, 1, 0, 6, 0, 7, 1, 6, 2, 0, 0, 1, 10, 0, 9, 0, 5, 9, 8, 9, 4, 3, 10, 3, 0, 2, 2, 4, 3, 7, 6, 10, 1, 9, 10, 9, 5, 0, 1, 0, 9, 3, 1, 9, 4, 2, 5, 0, 1, 7, 7, 3, 7, 2, 0, 4, 1, 3, 0, 0, 5, 5, 10, 0, 7, 8, 5, 10, 0, 0, 8, 5, 6, 7, 0, 1, 3, 3, 10, 0, 4, 9, 8, 6, 9, 3, 9, 0, 0, 1, 2, 4, 4, 6, 1, 1, 1, 6, 0, 1, 2, 1, 2, 0, 6, 7, 3, 6, 5, 9, 8, 1, 7, 2, 7, 8, 8, 3, 0, 7, 2, 7, 1, 0, 6, 3, 2, 5, 4, 1, 1, 4, 0, 0, 5, 5, 5, 0, 5, 5, 5, 0, 10, 0, 7, 8, 2, 10, 9, 4, 9, 7, 1, 7, 8, 6, 9, 10, 8, 10, 1, 10, 9, 9, 3, 3, 8, 0, 9, 9, 7, 9, 8, 10, 9, 8, 10, 6, 9, 7, 10, 7, 0, 7, 10, 9, 7, 10, 5, 5, 8, 9, 3, 10, 9, 7, 8, 10, 9, 5, 10, 4, 0, 10, 10, 10, 10, 3, 8, 7, 4, 3, 6, 6, 6, 0, 3, 1, 7, 4, 6, 5, 2, 1, 1, 4, 0, 1, 2, 1, 2, 0, 5, 6, 4, 3, 4, 6, 5, 1, 5, 1, 2, 5, 7, 2, 0, 1, 1, 5, 2, 0, 7, 4, 1, 6, 6, 1, 1, 6, 2, 1, 4, 5, 8, 0, 0, 1, 6, 2, 10, 4, 9, 5, 8, 
# ...

# %%
design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

total_llm = {}

for case in design_case:
    for criterion in design_criterion:
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

            with open(file_path, 'r') as f:
                data = json.load(f)
                total_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_total = {}

for m in materials:
    material_list_total[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            material_list_total[f"{material}"].append(total_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_total)
# Out:
# {'Steel': [3, 8, 7, 9, 3, 7, 7, 9, 3, 7, 5, 9, 2, 7, 7, 7], 'Aluminium': [8, 7, 6, 7, 8, 5, 8, 7, 8, 6, 7, 7, 7, 6, 8, 6], 'Titanium': [7, 9, 9, 8, 9, 9, 9, 10, 9, 8, 9, 10, 8, 8, 9, 8], 'Glass': [2, 5, 5, 2, 2, 3, 5, 2, 2, 5, 8, 3, 1, 2, 0, 2], 'Wood': [6, 2, 2, 6, 1, 0, 0, 0, 6, 0, 2, 1, 3, 0, 0, 3], 'Thermoplastic': [9, 1, 8, 7, 7, 2, 6, 6, 7, 4, 6, 6, 9, 5, 6, 7], 'Elastomer': [7, 1, 7, 5, 5, 1, 4, 3, 5, 3, 6, 5, 6, 4, 5, 5], 'Thermoset': [5, 3, 8, 7, 6, 4, 6, 5, 4, 5, 6, 6, 7, 7, 6, 7], 'Composite': [8, 6, 8, 8, 10, 8, 8, 8, 10, 7, 8, 8, 10, 9, 8, 9]}

# %%
survey_data_total = [list_material_total['Steel'], list_material_total['Aluminium'], list_material_total['Titanium'], list_material_total['Glass'], list_material_total['Wood'], list_material_total['Thermoplastic'], list_material_total['Elastomer'], list_material_total['Thermoset'], list_material_total['Composite']]
print(survey_data_total)
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_total[material] for material in materials]

ax.boxplot(data, labels=survey_labels_total)

llm_data_total = [material_list_total['Steel'], material_list_total['Aluminium'], material_list_total['Titanium'], material_list_total['Glass'], material_list_total['Wood'], material_list_total['Thermoplastic'], material_list_total['Elastomer'], material_list_total['Thermoset'], material_list_total['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_total) + 1), llm_data_total, 'ro', color =color, label='from LLM')
# colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'magenta', 'yellow', 'black']

# for i, material in enumerate(materials):
#     ax.plot(range(1, len(llm_data_total[i]) + 1), llm_data_total[i], 'o', color=colors[i], label=f'from LLM - {material}')
ax.set_xticklabels(survey_labels_total, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Total',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

plt.savefig('/Users/yashpatawari/Desktop/Design Research Collective/LLM for Materials/Results_Comparison/Box and Whisker/total.png', dpi=300, bbox_inches='tight')
# Out:
# [[0, 7, 7, 2, 5, 6, 3, 6, 0, 0, 1, 3, 3, 5, 1, 3, 1, 1, 5, 0, 1, 2, 2, 5, 0, 5, 3, 1, 4, 6, 3, 4, 0, 6, 2, 2, 3, 5, 3, 0, 6, 0, 5, 1, 0, 5, 5, 1, 5, 3, 1, 0, 6, 0, 7, 1, 6, 2, 0, 0, 1, 10, 0, 9, 0, 5, 9, 8, 9, 4, 3, 10, 3, 0, 2, 2, 4, 3, 7, 6, 10, 1, 9, 10, 9, 5, 0, 1, 0, 9, 3, 1, 9, 4, 2, 5, 0, 1, 7, 7, 3, 7, 2, 0, 4, 1, 3, 0, 0, 5, 5, 10, 0, 7, 8, 5, 10, 0, 0, 8, 5, 6, 7, 0, 1, 3, 3, 10, 0, 4, 9, 8, 6, 9, 3, 9, 0, 0, 1, 2, 4, 4, 6, 1, 1, 1, 6, 0, 1, 2, 1, 2, 0, 6, 7, 3, 6, 5, 9, 8, 1, 7, 2, 7, 8, 8, 3, 0, 7, 2, 7, 1, 0, 6, 3, 2, 5, 4, 1, 1, 4, 0, 0, 5, 5, 5, 0, 5, 5, 5, 0, 10, 0, 7, 8, 2, 10, 9, 4, 9, 7, 1, 7, 8, 6, 9, 10, 8, 10, 1, 10, 9, 9, 3, 3, 8, 0, 9, 9, 7, 9, 8, 10, 9, 8, 10, 6, 9, 7, 10, 7, 0, 7, 10, 9, 7, 10, 5, 5, 8, 9, 3, 10, 9, 7, 8, 10, 9, 5, 10, 4, 0, 10, 10, 10, 10, 3, 8, 7, 4, 3, 6, 6, 6, 0, 3, 1, 7, 4, 6, 5, 2, 1, 1, 4, 0, 1, 2, 1, 2, 0, 5, 6, 4, 3, 4, 6, 5, 1, 5, 1, 2, 5, 7, 2, 0, 1, 1, 5, 2, 0, 7, 4, 1, 6, 6, 1, 1, 6, 2, 1, 4, 5, 8, 0, 0, 1, 6, 2, 10, 4, 9, 5, 8,
# ...

# %%
import matplotlib.pyplot as plt

# Assuming list_material_total and material_list_total are defined earlier

survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
data_survey = [list_material_total[material] for material in survey_labels_total]
bp = ax.boxplot(data_survey,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_total = [material_list_total['Steel'], material_list_total['Aluminium'], material_list_total['Titanium'], material_list_total['Glass'], material_list_total['Wood'], material_list_total['Thermoplastic'], material_list_total['Elastomer'], material_list_total['Thermoset'], material_list_total['Composite']]
bp_2 = ax.boxplot(llm_data_total, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Total', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Design Cases

# %% [markdown]
# Kitchen Utensil Grip

# %%
import seaborn as sns
materials = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']


list_material_kitchen = {}
for material in materials:
    list_material_kitchen[material] = []
    for i in range(1, 5):
        list_material_kitchen[material].extend(df[f"Q{i}_{material}"])


print(list_material_kitchen['Steel'])
print(len(list_material_kitchen['Steel']))


design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

kitchen_llm = {}

for case in design_case:
    for criterion in design_criterion:
            if case == 'Kitchen Utensil Grip':
                file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

                with open(file_path, 'r') as f:
                    data = json.load(f)
                    kitchen_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_kitchen = {}

for m in materials:
    material_list_kitchen[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if case == 'Kitchen Utensil Grip':
                material_list_kitchen[f"{material}"].append(kitchen_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_kitchen)

survey_data_kitchen = [list_material_kitchen['Steel'], list_material_kitchen['Aluminium'], list_material_kitchen['Titanium'], list_material_kitchen['Glass'], list_material_kitchen['Wood'], list_material_kitchen['Thermoplastic'], list_material_kitchen['Elastomer'], list_material_kitchen['Thermoset'], list_material_kitchen['Composite']]
print(survey_data_kitchen)
survey_labels_kitchen = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_kitchen[material] for material in materials]

ax.boxplot(data, labels=survey_labels_kitchen)

llm_data_kitchen = [material_list_kitchen['Steel'], material_list_kitchen['Aluminium'], material_list_kitchen['Titanium'], material_list_kitchen['Glass'], material_list_kitchen['Wood'], material_list_kitchen['Thermoplastic'], material_list_kitchen['Elastomer'], material_list_kitchen['Thermoset'], material_list_kitchen['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_kitchen) + 1), llm_data_kitchen, 'o', color =color, label='from LLM')
# cmap = plt.get_cmap('tab10')
# colors = [cmap(i) for i in range(len(materials))]

# # Plot the data points with different colors
# for i, material in enumerate(materials):
#     scatter = ax.plot(range(1, len(material_list_kitchen[material]) + 1), material_list_kitchen[material], 'o', color=colors[i], label=f'from LLM - {material}')


# colors = ['red', 'green', 'blue', 'orange', 'purple', 'cyan', 'magenta', 'yellow', 'black']

# for i, material in enumerate(materials):
#     ax.plot(range(1, len(llm_data_total[i]) + 1), llm_data_total[i], 'o', color=colors[i], label=f'from LLM - {material}')
ax.set_xticklabels(survey_labels_kitchen, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Kitchen Utensil Grip',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
plt.savefig('/Users/yashpatawari/Desktop/Design Research Collective/LLM for Materials/Results_Comparison/Box and Whisker/kitchen.png', dpi=300, bbox_inches='tight')
# Out:
# [0, 7, 7, 2, 5, 6, 3, 6, 0, 0, 1, 3, 3, 5, 1, 3, 1, 1, 5, 0, 1, 2, 2, 5, 0, 5, 3, 1, 4, 6, 3, 4, 0, 6, 2, 2, 3, 5, 3, 0, 6, 0, 5, 1, 0, 5, 5, 1, 5, 3, 1, 0, 6, 0, 7, 1, 6, 2, 0, 0, 1, 10, 0, 9, 0, 5, 9, 8, 9, 4, 3, 10, 3, 0, 2, 2, 4, 3, 7, 6, 10, 1, 9, 10, 9, 5, 0, 1, 0, 9, 3, 1, 9, 4, 2, 5, 0, 1, 7, 7, 3, 7, 2, 0, 4, 1, 3, 0, 0, 5, 5, 10, 0, 7, 8, 5, 10, 0, 0, 8, 5, 6, 7, 0, 1, 3, 3, 10, 0, 4, 9, 8, 6, 9, 3, 9, 0, 0, 1, 2, 4, 4, 6, 1, 1, 1, 6, 0, 1, 2, 1, 2, 0, 6, 7, 3, 6, 5, 9, 8, 1, 7, 2, 7, 8, 8, 3, 0, 7, 2, 7, 1, 0, 6, 3, 2, 5, 4, 1, 1, 4, 0, 0, 5, 5, 5, 0, 5, 5, 5, 0, 10, 0, 7, 8, 2, 10, 9, 4, 9, 7, 1, 7, 8, 6, 9, 10, 8, 10, 1, 10, 9, 9, 3, 3, 8, 0, 9, 9, 7, 9, 8, 10, 9, 8, 10, 6, 9, 7, 10, 7, 0, 7, 10, 9, 7, 10, 5, 5, 8, 9, 3, 10, 9, 7, 8, 10, 9, 5, 10, 4, 0, 10, 10, 10, 10]
# 256
# ...

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_kitchen = [list_material_kitchen[material] for material in materials]
bp = ax.boxplot(data_survey_kitchen,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
# llm_data_total = [material_list_total['Steel'], material_list_total['Aluminium'], material_list_total['Titanium'], material_list_total['Glass'], material_list_total['Wood'], material_list_total['Thermoplastic'], material_list_total['Elastomer'], material_list_total['Thermoset'], material_list_total['Composite']]
llm_data_kitchen = [material_list_kitchen['Steel'], material_list_kitchen['Aluminium'], material_list_kitchen['Titanium'], material_list_kitchen['Glass'], material_list_kitchen['Wood'], material_list_kitchen['Thermoplastic'], material_list_kitchen['Elastomer'], material_list_kitchen['Thermoset'], material_list_kitchen['Composite']]
bp_2 = ax.boxplot(llm_data_kitchen, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Kitchen Utensil Grip', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))
# ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# handles, labels = ax.get_legend_handles_labels()

# ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.tight_layout()
plt.show()

# %% [markdown]
# Spacecraft Component

# %%
list_material_spacecraft = {}
for material in materials:
    list_material_spacecraft[material] = []
    for i in range(5, 9):
        list_material_spacecraft[material].extend(df[f"Q{i}_{material}"])


print(list_material_spacecraft['Steel'])
print(len(list_material_spacecraft['Steel']))


design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

spacecraft_llm = {}

for case in design_case:
    for criterion in design_criterion:
            if case == 'Spacecraft Component':
                file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

                with open(file_path, 'r') as f:
                    data = json.load(f)
                    spacecraft_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_spacecraft = {}

for m in materials:
    material_list_spacecraft[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if case == 'Spacecraft Component':
                material_list_spacecraft[f"{material}"].append(spacecraft_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_spacecraft)

survey_data_spacecraft = [list_material_spacecraft['Steel'], list_material_spacecraft['Aluminium'], list_material_spacecraft['Titanium'], list_material_spacecraft['Glass'], list_material_spacecraft['Wood'], list_material_spacecraft['Thermoplastic'], list_material_spacecraft['Elastomer'], list_material_spacecraft['Thermoset'], list_material_spacecraft['Composite']]
print(survey_data_spacecraft)
survey_labels_spacecraft = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_spacecraft[material] for material in materials]

ax.boxplot(data, labels=survey_labels_spacecraft)

llm_data_spacecraft = [material_list_spacecraft['Steel'], material_list_spacecraft['Aluminium'], material_list_spacecraft['Titanium'], material_list_spacecraft['Glass'], material_list_spacecraft['Wood'], material_list_spacecraft['Thermoplastic'], material_list_spacecraft['Elastomer'], material_list_spacecraft['Thermoset'], material_list_spacecraft['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_spacecraft) + 1), llm_data_spacecraft, 'o', color =color, label='from LLM')

ax.set_xticklabels(survey_labels_spacecraft, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Spacecraft Component',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# [3, 8, 7, 4, 3, 6, 6, 6, 0, 3, 1, 7, 4, 6, 5, 2, 1, 1, 4, 0, 1, 2, 1, 2, 0, 5, 6, 4, 3, 4, 6, 5, 1, 5, 1, 2, 5, 7, 2, 0, 1, 1, 5, 2, 0, 7, 4, 1, 6, 6, 1, 1, 6, 2, 1, 4, 5, 8, 0, 0, 1, 6, 2, 10, 4, 9, 5, 8, 9, 8, 7, 9, 4, 0, 3, 7, 4, 9, 7, 6, 1, 1, 6, 9, 8, 1, 6, 5, 4, 7, 4, 4, 8, 4, 9, 10, 3, 3, 5, 4, 9, 8, 6, 0, 5, 8, 2, 2, 10, 6, 3, 7, 8, 7, 2, 1, 7, 2, 10, 9, 5, 7, 1, 0, 7, 5, 2, 10, 0, 4, 8, 6, 10, 6, 6, 10, 3, 1, 1, 3, 3, 5, 5, 5, 1, 1, 8, 0, 3, 4, 2, 5, 1, 5, 1, 4, 7, 5, 2, 8, 5, 4, 3, 7, 8, 7, 1, 0, 5, 5, 2, 1, 0, 4, 4, 1, 6, 7, 1, 1, 8, 4, 0, 6, 4, 8, 1, 0, 1, 5, 2, 10, 0, 8, 3, 8, 6, 9, 8, 10, 8, 8, 8, 7, 3, 8, 10, 9, 1, 9, 5, 1, 6, 1, 7, 10, 5, 8, 8, 6, 7, 7, 9, 10, 8, 8, 4, 8, 7, 8, 8, 0, 5, 10, 6, 4, 10, 7, 3, 8, 8, 6, 2, 6, 8, 7, 10, 9, 8, 10, 0, 10, 7, 10, 8, 10]
# 256
# ...

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_spacecraft = [list_material_spacecraft[material] for material in materials]
bp = ax.boxplot(data_survey_spacecraft,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_spacecraft = [material_list_spacecraft[material] for material in materials]
bp_2 = ax.boxplot(llm_data_spacecraft, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Spacecraft Component', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# Underwater Component

# %%
list_material_underwater = {}
for material in materials:
    list_material_underwater[material] = []
    for i in range(9, 13):
        list_material_underwater[material].extend(df[f"Q{i}_{material}"])


print(list_material_underwater['Steel'])
print(len(list_material_underwater['Steel']))


design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

underwater_llm = {}

for case in design_case:
    for criterion in design_criterion:
            if case == 'Underwater Component':
                file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

                with open(file_path, 'r') as f:
                    data = json.load(f)
                    underwater_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_underwater = {}

for m in materials:
    material_list_underwater[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if case == 'Underwater Component':
                material_list_underwater[f"{material}"].append(underwater_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_underwater)

survey_data_underwater = [list_material_underwater['Steel'], list_material_underwater['Aluminium'], list_material_underwater['Titanium'], list_material_underwater['Glass'], list_material_underwater['Wood'], list_material_underwater['Thermoplastic'], list_material_underwater['Elastomer'], list_material_underwater['Thermoset'], list_material_underwater['Composite']]
print(survey_data_underwater)
survey_labels_underwater = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_underwater[material] for material in materials]

ax.boxplot(data, labels=survey_labels_underwater)

llm_data_underwater = [material_list_underwater['Steel'], material_list_underwater['Aluminium'], material_list_underwater['Titanium'], material_list_underwater['Glass'], material_list_underwater['Wood'], material_list_underwater['Thermoplastic'], material_list_underwater['Elastomer'], material_list_underwater['Thermoset'], material_list_underwater['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_underwater) + 1), llm_data_underwater, 'o', color =color, label='from LLM')

ax.set_xticklabels(survey_labels_underwater, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Underwater Component',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# [0, 7, 7, 2, 9, 6, 3, 6, 1, 0, 1, 6, 5, 1, 5, 2, 1, 1, 4, 0, 1, 1, 1, 2, 2, 4, 2, 4, 5, 4, 6, 5, 1, 5, 2, 3, 4, 6, 1, 0, 6, 2, 5, 1, 10, 3, 8, 2, 3, 8, 5, 1, 7, 2, 0, 4, 7, 8, 0, 0, 2, 5, 5, 10, 0, 7, 9, 10, 9, 9, 7, 10, 1, 5, 8, 3, 6, 8, 10, 5, 4, 1, 7, 0, 6, 4, 5, 10, 5, 8, 2, 6, 8, 6, 9, 10, 5, 3, 6, 6, 10, 8, 7, 0, 4, 5, 4, 3, 10, 7, 9, 9, 5, 9, 6, 9, 8, 5, 9, 9, 9, 9, 5, 7, 6, 10, 10, 10, 1, 8, 7, 9, 9, 4, 6, 10, 0, 1, 1, 4, 4, 7, 2, 1, 1, 1, 6, 0, 1, 5, 1, 1, 0, 5, 6, 2, 6, 4, 9, 9, 1, 5, 2, 4, 8, 2, 4, 1, 5, 5, 4, 0, 0, 5, 3, 1, 7, 5, 5, 1, 4, 2, 0, 10, 4, 5, 1, 0, 1, 6, 5, 10, 0, 3, 5, 7, 9, 9, 9, 9, 3, 9, 6, 7, 7, 10, 7, 6, 9, 1, 9, 10, 7, 4, 0, 9, 5, 9, 10, 7, 8, 7, 10, 10, 7, 9, 4, 8, 10, 9, 0, 1, 8, 10, 6, 4, 10, 6, 3, 0, 7, 7, 7, 3, 7, 7, 10, 10, 9, 10, 5, 0, 6, 10, 10, 10]
# 256
# ...

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_underwater = [list_material_underwater[material] for material in materials]
bp = ax.boxplot(data_survey_underwater,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_underwater = [material_list_underwater[material] for material in materials]
bp_2 = ax.boxplot(llm_data_underwater, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Underwater Component', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# Safety Helmet

# %%
list_material_safety_helmet = {}
for material in materials:
    list_material_safety_helmet[material] = []
    for i in range(13, 17):
        list_material_safety_helmet[material].extend(df[f"Q{i}_{material}"])


print(list_material_safety_helmet['Steel'])
print(len(list_material_safety_helmet['Steel']))


design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

safety_helmet_llm = {}

for case in design_case:
    for criterion in design_criterion:
            if case == 'Safety Helmet':
                file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

                with open(file_path, 'r') as f:
                    data = json.load(f)
                    safety_helmet_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_safety_helmet = {}

for m in materials:
    material_list_safety_helmet[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if case == 'Safety Helmet':
                material_list_safety_helmet[f"{material}"].append(safety_helmet_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_safety_helmet)

survey_data_safety_helmet = [list_material_safety_helmet['Steel'], list_material_safety_helmet['Aluminium'], list_material_safety_helmet['Titanium'], list_material_safety_helmet['Glass'], list_material_safety_helmet['Wood'], list_material_safety_helmet['Thermoplastic'], list_material_safety_helmet['Elastomer'], list_material_safety_helmet['Thermoset'], list_material_safety_helmet['Composite']]
print(survey_data_safety_helmet)
survey_labels_safety_helmet = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_safety_helmet[material] for material in materials]

ax.boxplot(data, labels=survey_labels_safety_helmet)

llm_data_safety_helmet = [material_list_safety_helmet['Steel'], material_list_safety_helmet['Aluminium'], material_list_safety_helmet['Titanium'], material_list_safety_helmet['Glass'], material_list_safety_helmet['Wood'], material_list_safety_helmet['Thermoplastic'], material_list_safety_helmet['Elastomer'], material_list_safety_helmet['Thermoset'], material_list_safety_helmet['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_safety_helmet) + 1), llm_data_safety_helmet, 'o', color =color, label='from LLM')

ax.set_xticklabels(survey_labels_safety_helmet, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Safety Helmet',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# [1, 3, 1, 1, 0, 2, 2, 7, 0, 1, 1, 1, 1, 2, 3, 1, 1, 1, 7, 0, 1, 1, 0, 2, 0, 5, 2, 2, 2, 4, 0, 5, 0, 5, 1, 2, 1, 8, 3, 0, 3, 1, 4, 4, 0, 3, 7, 2, 2, 8, 3, 1, 3, 0, 1, 2, 3, 1, 0, 0, 5, 1, 0, 8, 2, 7, 5, 10, 0, 5, 3, 10, 0, 0, 1, 1, 2, 8, 6, 5, 1, 1, 7, 1, 1, 1, 1, 8, 5, 7, 1, 4, 5, 6, 0, 10, 9, 1, 3, 2, 9, 8, 5, 0, 3, 2, 1, 4, 0, 4, 3, 8, 1, 8, 2, 10, 10, 5, 0, 7, 5, 3, 4, 0, 10, 2, 0, 10, 0, 6, 9, 9, 5, 6, 4, 10, 0, 1, 1, 1, 1, 6, 5, 2, 1, 1, 5, 0, 1, 1, 1, 3, 2, 4, 1, 2, 4, 5, 0, 9, 2, 7, 3, 5, 6, 6, 2, 0, 1, 0, 1, 4, 0, 4, 3, 0, 4, 8, 5, 6, 5, 2, 1, 4, 5, 2, 0, 0, 1, 2, 0, 10, 0, 3, 4, 1, 5, 9, 3, 10, 1, 5, 1, 1, 2, 9, 10, 8, 1, 9, 10, 8, 9, 1, 6, 7, 10, 7, 3, 2, 9, 6, 5, 10, 7, 8, 7, 2, 2, 8, 6, 0, 8, 10, 7, 4, 0, 5, 3, 8, 6, 9, 7, 7, 8, 7, 10, 7, 8, 10, 4, 0, 10, 10, 0, 10]
# 256
# ...

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_safety_helmet = [list_material_safety_helmet[material] for material in materials]
bp = ax.boxplot(data_survey_safety_helmet,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_safety_helmet = [material_list_safety_helmet[material] for material in materials]
bp_2 = ax.boxplot(llm_data_safety_helmet, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Safety Helmet', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Design Criterion

# %% [markdown]
# Lightweight

# %%
list_material_lightweight = {}
for material in materials:
    list_material_lightweight[material] = []
    for i in range(1, 17, 4):
        list_material_lightweight[material].extend(df[f"Q{i}_{material}"])


print(list_material_lightweight['Steel'])
print(len(list_material_lightweight['Steel']))


design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

lightweight_llm = {}

for case in design_case:
    for criterion in design_criterion:
            if criterion == 'Lightweight':
                file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
        

                with open(file_path, 'r') as f:
                    data = json.load(f)
                    lightweight_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_lightweight = {}

for m in materials:
    material_list_lightweight[f"{m}"] = []


for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if criterion == 'Lightweight':
                material_list_lightweight[f"{material}"].append(lightweight_llm[f"{case}_{criterion}"][f"{material}"])

print(material_list_lightweight)

survey_data_lightweight = [list_material_lightweight['Steel'], list_material_lightweight['Aluminium'], list_material_lightweight['Titanium'], list_material_lightweight['Glass'], list_material_lightweight['Wood'], list_material_lightweight['Thermoplastic'], list_material_lightweight['Elastomer'], list_material_lightweight['Thermoset'], list_material_lightweight['Composite']]
print(survey_data_lightweight)
survey_labels_lightweight = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_lightweight[material] for material in materials]

ax.boxplot(data, labels=survey_labels_lightweight)

llm_data_lightweight = [material_list_lightweight['Steel'], material_list_lightweight['Aluminium'], material_list_lightweight['Titanium'], material_list_lightweight['Glass'], material_list_lightweight['Wood'], material_list_lightweight['Thermoplastic'], material_list_lightweight['Elastomer'], material_list_lightweight['Thermoset'], material_list_lightweight['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_lightweight) + 1), llm_data_lightweight, 'o', color =color, label='from LLM')

ax.set_xticklabels(survey_labels_lightweight, rotation=45)
                  

ax.set_title('Box and Whisker Plot - Lightweight',fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# ax.legend(loc='upper right')
handles, labels = ax.get_legend_handles_labels()

ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()
# Out:
# [0, 7, 7, 2, 5, 6, 3, 6, 0, 0, 1, 3, 3, 5, 1, 3, 1, 1, 5, 0, 1, 2, 2, 5, 0, 5, 3, 1, 4, 6, 3, 4, 0, 6, 2, 2, 3, 5, 3, 0, 6, 0, 5, 1, 0, 5, 5, 1, 5, 3, 1, 0, 6, 0, 7, 1, 6, 2, 0, 0, 1, 10, 0, 9, 3, 8, 7, 4, 3, 6, 6, 6, 0, 3, 1, 7, 4, 6, 5, 2, 1, 1, 4, 0, 1, 2, 1, 2, 0, 5, 6, 4, 3, 4, 6, 5, 1, 5, 1, 2, 5, 7, 2, 0, 1, 1, 5, 2, 0, 7, 4, 1, 6, 6, 1, 1, 6, 2, 1, 4, 5, 8, 0, 0, 1, 6, 2, 10, 0, 7, 7, 2, 9, 6, 3, 6, 1, 0, 1, 6, 5, 1, 5, 2, 1, 1, 4, 0, 1, 1, 1, 2, 2, 4, 2, 4, 5, 4, 6, 5, 1, 5, 2, 3, 4, 6, 1, 0, 6, 2, 5, 1, 10, 3, 8, 2, 3, 8, 5, 1, 7, 2, 0, 4, 7, 8, 0, 0, 2, 5, 5, 10, 1, 3, 1, 1, 0, 2, 2, 7, 0, 1, 1, 1, 1, 2, 3, 1, 1, 1, 7, 0, 1, 1, 0, 2, 0, 5, 2, 2, 2, 4, 0, 5, 0, 5, 1, 2, 1, 8, 3, 0, 3, 1, 4, 4, 0, 3, 7, 2, 2, 8, 3, 1, 3, 0, 1, 2, 3, 1, 0, 0, 5, 1, 0, 8]
# 256
# ...

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_lightweight = [list_material_lightweight[material] for material in materials]
bp = ax.boxplot(data_survey_lightweight,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_lightweight = [material_list_lightweight[material] for material in materials]
bp_2 = ax.boxplot(llm_data_lightweight, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Lightweight', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# Resistant to Heat

# %%
list_material_resistant_to_heat = {}
for material in materials:
    list_material_resistant_to_heat[material] = []
    for i in range(2, 17, 4):
        list_material_resistant_to_heat[material].extend(df[f"Q{i}_{material}"])

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

resistant_to_heat_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'Resistant to Heat':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
            with open(file_path, 'r') as f:
                data = json.load(f)
                resistant_to_heat_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_resistant_to_heat = {}

for m in materials:
    material_list_resistant_to_heat[f"{m}"] = []

for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if criterion == 'Resistant to Heat':
                material_list_resistant_to_heat[f"{material}"].append(resistant_to_heat_llm[f"{case}_{criterion}"][f"{material}"])

survey_data_resistant_to_heat = [list_material_resistant_to_heat['Steel'], list_material_resistant_to_heat['Aluminium'], list_material_resistant_to_heat['Titanium'], list_material_resistant_to_heat['Glass'], list_material_resistant_to_heat['Wood'], list_material_resistant_to_heat['Thermoplastic'], list_material_resistant_to_heat['Elastomer'], list_material_resistant_to_heat['Thermoset'], list_material_resistant_to_heat['Composite']]

survey_labels_resistant_to_heat = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_resistant_to_heat[material] for material in materials]

ax.boxplot(data, labels=survey_labels_resistant_to_heat)

llm_data_resistant_to_heat = [material_list_resistant_to_heat['Steel'], material_list_resistant_to_heat['Aluminium'], material_list_resistant_to_heat['Titanium'], material_list_resistant_to_heat['Glass'], material_list_resistant_to_heat['Wood'], material_list_resistant_to_heat['Thermoplastic'], material_list_resistant_to_heat['Elastomer'], material_list_resistant_to_heat['Thermoset'], material_list_resistant_to_heat['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_resistant_to_heat) + 1), llm_data_resistant_to_heat, 'o', color=color, label='from LLM')

ax.set_xticklabels(survey_labels_resistant_to_heat, rotation=45)

ax.set_title('Box and Whisker Plot - Resistant to Heat', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_resistant_to_heat = [list_material_resistant_to_heat[material] for material in materials]
bp = ax.boxplot(data_survey_resistant_to_heat,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_resistant_to_heat = [material_list_resistant_to_heat[material] for material in materials]
bp_2 = ax.boxplot(llm_data_resistant_to_heat, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Resistant to Heat', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# Corrosion Resistant

# %%
list_material_corrosion_resistant = {}
for material in materials:
    list_material_corrosion_resistant[material] = []
    for i in range(3, 17, 4):
        list_material_corrosion_resistant[material].extend(df[f"Q{i}_{material}"])

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

corrosion_resistant_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'Corrosion Resistant':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
            with open(file_path, 'r') as f:
                data = json.load(f)
                corrosion_resistant_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_corrosion_resistant = {}

for m in materials:
    material_list_corrosion_resistant[f"{m}"] = []

for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if criterion == 'Corrosion Resistant':
                material_list_corrosion_resistant[f"{material}"].append(corrosion_resistant_llm[f"{case}_{criterion}"][f"{material}"])

survey_data_corrosion_resistant = [list_material_corrosion_resistant['Steel'], list_material_corrosion_resistant['Aluminium'], list_material_corrosion_resistant['Titanium'], list_material_corrosion_resistant['Glass'], list_material_corrosion_resistant['Wood'], list_material_corrosion_resistant['Thermoplastic'], list_material_corrosion_resistant['Elastomer'], list_material_corrosion_resistant['Thermoset'], list_material_corrosion_resistant['Composite']]

survey_labels_corrosion_resistant = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_corrosion_resistant[material] for material in materials]

ax.boxplot(data, labels=survey_labels_corrosion_resistant)

llm_data_corrosion_resistant = [material_list_corrosion_resistant['Steel'], material_list_corrosion_resistant['Aluminium'], material_list_corrosion_resistant['Titanium'], material_list_corrosion_resistant['Glass'], material_list_corrosion_resistant['Wood'], material_list_corrosion_resistant['Thermoplastic'], material_list_corrosion_resistant['Elastomer'], material_list_corrosion_resistant['Thermoset'], material_list_corrosion_resistant['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_corrosion_resistant) + 1), llm_data_corrosion_resistant, 'o', color=color, label='from LLM')

ax.set_xticklabels(survey_labels_corrosion_resistant, rotation=45)

ax.set_title('Box and Whisker Plot - Corrosion Resistant', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_corrosion_resistant = [list_material_corrosion_resistant[material] for material in materials]
bp = ax.boxplot(data_survey_corrosion_resistant,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_corrosion_resistant = [material_list_corrosion_resistant[material] for material in materials]
bp_2 = ax.boxplot(llm_data_corrosion_resistant, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - Corrosion Resistant', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# High Strength

# %%
list_material_high_strength = {}
for material in materials:
    list_material_high_strength[material] = []
    for i in range(4, 17, 4):
        list_material_high_strength[material].extend(df[f"Q{i}_{material}"])

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant' ,'High Strength']

high_strength_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'High Strength':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
            with open(file_path, 'r') as f:
                data = json.load(f)
                high_strength_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_high_strength = {}

for m in materials:
    material_list_high_strength[f"{m}"] = []

for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if criterion == 'High Strength':
                material_list_high_strength[f"{material}"].append(high_strength_llm[f"{case}_{criterion}"][f"{material}"])

survey_data_high_strength = [list_material_high_strength['Steel'], list_material_high_strength['Aluminium'], list_material_high_strength['Titanium'], list_material_high_strength['Glass'], list_material_high_strength['Wood'], list_material_high_strength['Thermoplastic'], list_material_high_strength['Elastomer'], list_material_high_strength['Thermoset'], list_material_high_strength['Composite']]

survey_labels_high_strength = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_high_strength[material] for material in materials]

bp = ax.boxplot(data, labels=survey_labels_high_strength)
 
colors = ['#0000FF', '#00FF00', 
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    for median in bp['medians']:
        median.set(color ='blue',linewidth = 3)
 

llm_data_high_strength = [material_list_high_strength['Steel'], material_list_high_strength['Aluminium'], material_list_high_strength['Titanium'], material_list_high_strength['Glass'], material_list_high_strength['Wood'], material_list_high_strength['Thermoplastic'], material_list_high_strength['Elastomer'], material_list_high_strength['Thermoset'], material_list_high_strength['Composite']]

color = 'tab:orange'
ax.plot(range(1, len(llm_data_high_strength) + 1), llm_data_high_strength, 'o', color=color, label='from LLM')

ax.set_xticklabels(survey_labels_high_strength, rotation=45)

ax.set_title('Box and Whisker Plot - High Strength', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
list_material_high_strength = {}
for material in materials:
    list_material_high_strength[material] = []
    for i in range(4, 17, 4):
        list_material_high_strength[material].extend(df[f"Q{i}_{material}"])

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant' ,'High Strength']

high_strength_llm = {}

for case in design_case:
    for criterion in design_criterion:
        if criterion == 'High Strength':
            file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
            with open(file_path, 'r') as f:
                data = json.load(f)
                high_strength_llm[f"{case}_{criterion}"] = ast.literal_eval(data)

material_list_high_strength = {}

for m in materials:
    material_list_high_strength[f"{m}"] = []

for case in design_case:
    for criterion in design_criterion:
        for material in materials:
            if criterion == 'High Strength':
                material_list_high_strength[f"{material}"].append(high_strength_llm[f"{case}_{criterion}"][f"{material}"])

survey_data_high_strength = [list_material_high_strength['Steel'], list_material_high_strength['Aluminium'], list_material_high_strength['Titanium'], list_material_high_strength['Glass'], list_material_high_strength['Wood'], list_material_high_strength['Thermoplastic'], list_material_high_strength['Elastomer'], list_material_high_strength['Thermoset'], list_material_high_strength['Composite']]

survey_labels_high_strength = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

data = [list_material_high_strength[material] for material in materials]

bp = ax.boxplot(data, labels=survey_labels_high_strength)
 
colors = ['#0000FF', '#00FF00', 
          '#FFFF00', '#FF00FF']
 
for patch, color in zip(bp['boxes'], colors):
    for median in bp['medians']:
        median.set(color ='blue',linewidth = 3)
 

llm_data_high_strength = [material_list_high_strength['Steel'], material_list_high_strength['Aluminium'], material_list_high_strength['Titanium'], material_list_high_strength['Glass'], material_list_high_strength['Wood'], material_list_high_strength['Thermoplastic'], material_list_high_strength['Elastomer'], material_list_high_strength['Thermoset'], material_list_high_strength['Composite']]


llm_counts = {material: {value: llm_data_high_strength.count(value) for value in set(llm_data_high_strength[material])} for material in range(len(llm_data_high_strength))}

# Calculate marker sizes based on occurrences
marker_sizes = []
for material in range(len(llm_data_high_strength)):
    sizes = [llm_counts[material][value] * 100 if llm_counts[material][value] > 1 else 50 for value in llm_data_high_strength[material]]
    marker_sizes.append(sizes)

# Plotting with customized marker sizes
color = 'tab:orange'
for i, sizes in enumerate(marker_sizes):
    ax.scatter([i+1] * len(sizes), llm_data_high_strength[i], s=sizes, color=color, label='from LLM')
# color = 'tab:orange'
# ax.plot(range(1, len(llm_data_high_strength) + 1), llm_data_high_strength, 'o', color=color, label='from LLM')

ax.set_xticklabels(survey_labels_high_strength, rotation=45)

ax.set_title('Box and Whisker Plot - High Strength', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles, labels, loc='center left', bbox_to_anchor=(1, 0.5))

plt.show()

# %%
survey_labels_total = ['Steel', 'Aluminium', 'Titanium', 'Glass', 'Wood', 'Thermoplastic', 'Elastomer', 'Thermoset', 'Composite']

fig, ax = plt.subplots(figsize=(12, 10))

# Plot boxplot for survey data
# data_survey = [list_material_total[material] for material in survey_labels_total]
data_survey_high_strength = [list_material_high_strength[material] for material in materials]
bp = ax.boxplot(data_survey_high_strength,  positions=[i - 0.2 for i in range(len(survey_labels_total))], widths=0.3,labels=survey_labels_total,patch_artist=True, boxprops=dict(facecolor='pink'))

# Plot boxplot for LLM data
llm_data_high_strength = [material_list_high_strength[material] for material in materials]
bp_2 = ax.boxplot(llm_data_high_strength, positions=[i + 0.2 for i in range(len(survey_labels_total))],widths=0.3, patch_artist=True, boxprops=dict(facecolor='skyblue'), showfliers=False)

for median in bp['medians']:
    median.set(color ='black',linewidth = 2)

for median in bp_2['medians']:
        median.set(color ='black',linewidth = 2)

ax.set_xticks([i for i in range(len(survey_labels_total))])
ax.set_xticklabels(survey_labels_total, rotation=45)

ax.set_title('Box and Whisker Plot - High Strength', fontsize=18)
ax.set_xlabel('Materials', fontsize=14)
ax.set_ylabel('Scores', fontsize=14)

# Create custom legends
survey_legend = plt.Line2D([], [], marker='o', color='pink', label='from Survey')
llm_legend = plt.Line2D([], [], marker='o', color='skyblue', label='from LLM')
ax.legend(handles=[survey_legend, llm_legend], loc='center left', bbox_to_anchor=(1, 0.5))


plt.tight_layout()
plt.show()

# %% [markdown]
# ## 4x4

# %% [markdown]
# Q1

# %%
q1_survey_dict = {}
q1_survey_dict_std = {}
for m in materials:
    q1_survey_dict[m] = df[f"Q1_{m}"].mean()
    q1_survey_dict_std[m] = df[f"Q1_{m}"].std()

print(q1_survey_dict['Steel'])
print(q1_survey_dict_std['Steel'])

design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']

q1_llm = {}

file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/Kitchen Utensil Grip_Lightweight.json'
        

with open(file_path, 'r') as f:
    data = json.load(f)
    q1_llm[f"Kitchen Utensil Grip_Lightweight"] = ast.literal_eval(data)

material_list_q1 = {}

for m in materials:
    material_list_q1[f"{m}"] = []

for material in materials:
    # material_list_q1[f"{material}"].append(q1_llm["Kitchen Utensil Grip_Lightweight"][f"{material}"])
    material_list_q1[f"{material}"] = q1_llm["Kitchen Utensil Grip_Lightweight"][f"{material}"]

print(material_list_q1)


survey_list_q1 = [q1_survey_dict[material] for material in materials]
std_list_q1 = [q1_survey_dict_std[material] for material in materials]
llm_list_q1 = [material_list_q1[material] for material in materials]

print(llm_list_q1)

data_q1 = pd.DataFrame({
    'Materials': materials * 2,
    'Scores': survey_list_q1 + llm_list_q1,
    'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
})

plt.figure(figsize=(10, 6))
color_palette = sns.color_palette("colorblind")

# Plot the bar chart with the colorblind-friendly palette
sns.barplot(x='Materials', y='Scores', hue='Source', data=data_q1[:len(materials)], palette=color_palette, yerr=std_list_q1[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
sns.scatterplot(x='Materials', y='Scores', hue='Source', data=data_q1[len(materials):], palette="Set2", s=100)

plt.xlabel('Materials', fontsize=12)
plt.ylabel('Scores', fontsize=12)
plt.ylim(0,10)
plt.title('Design Criterion 4 (High Strength): Total Averaged out Scores', fontsize=16)
plt.xticks(rotation=45, ha='right')
plt.legend(title='Source')
plt.show()
# Out:
# 2.96875
# 2.5632862711637396
# {'Steel': 3, 'Aluminium': 8, 'Titanium': 7, 'Glass': 2, 'Wood': 6, 'Thermoplastic': 9, 'Elastomer': 7, 'Thermoset': 5, 'Composite': 8}
# [3, 8, 7, 2, 6, 9, 7, 5, 8]

# %% [markdown]
# q2

# %%
def process_quarter_data(q):
   q_survey_dict = {}
   q_survey_dict_std = {}
   material_list_q = {}
   llm_list_q = {}

   design_case = ['Kitchen Utensil Grip', 'Spacecraft Component', 'Underwater Component', 'Safety Helmet']
   design_criterion = ['Lightweight', 'Resistant to Heat', 'Corrosion Resistant', 'High Strength']
   
   if q == "Q2":
    case = design_case[0]
    criterion = design_criterion[1]
   elif q == "Q3":
    case = design_case[0]
    criterion = design_criterion[2]
   elif q == "Q4":
    case = design_case[0]
    criterion = design_criterion[3]
   elif q == "Q16":
    case = design_case[3]
    criterion = design_criterion[3]
   elif q == "Q5":
    case = design_case[1]
    criterion = design_criterion[0]
   elif q == "Q6":
    case = design_case[1]
    criterion = design_criterion[1]
   elif q == "Q7":
    case = design_case[1]
    criterion = design_criterion[2]
   elif q == "Q8":
    case = design_case[1]
    criterion = design_criterion[3]
   elif q == "Q9":
    case = design_case[2]
    criterion = design_criterion[0]
   elif q == "Q10":
    case = design_case[2]
    criterion = design_criterion[1]
   elif q == "Q11":
    case = design_case[2]
    criterion = design_criterion[2]
   elif q == "Q12":
    case = design_case[2]
    criterion = design_criterion[3]
   elif q == "Q13":
    case = design_case[3]
    criterion = design_criterion[0]
   elif q == "Q14":
    case = design_case[3]
    criterion = design_criterion[1]
   elif q == "Q15":
    case = design_case[3]
    criterion = design_criterion[2]
     
    
   for material in materials:
    # Calculate survey mean and standard deviation
    q_survey_dict[material] = df[f"{q}_{material}"].mean()
    q_survey_dict_std[material] = df[f"{q}_{material}"].std()

    # Create empty lists for material data from LLM
    material_list_q[f"{material}"] = []

   

  # Load LLM data for the current quarter
   file_path = f'/Users/yashpatawari/LLM-for-Material-Selection/All 10_GPT4/{case}_{criterion}.json'
   with open(file_path, 'r') as f:
      data = json.load(f)
      llm_list_q[f"{case}_{criterion}"] = ast.literal_eval(data)

  # Populate material list with LLM data
   for material in materials:
      material_list_q[f"{material}"] = llm_list_q[f"{case}_{criterion}"][f"{material}"]

  # Create lists from dictionaries for DataFrame creation
   survey_list_q = [q_survey_dict[material] for material in materials]
   std_list_q = [q_survey_dict_std[material] for material in materials]
   llm_list_q = [material_list_q[material] for material in materials]

  # Create DataFrame
   data_q = pd.DataFrame({
      'Materials': materials * 2,
      'Scores': survey_list_q + llm_list_q,
      'Source': ['from_Survey'] * len(materials) + ['from_LLM'] * len(materials)
  })

   return data_q, std_list_q

# Call the function for each quarter (assuming Q2, Q3, and Q4)
data_q2, std_list_q2 = process_quarter_data("Q2")
data_q3, std_list_q3 = process_quarter_data("Q3")
data_q4, std_list_q4 = process_quarter_data("Q4")
data_q5, std_list_q5 = process_quarter_data("Q5")
data_q6, std_list_q6 = process_quarter_data("Q6")
data_q7, std_list_q7 = process_quarter_data("Q7")
data_q8, std_list_q8 = process_quarter_data("Q8")
data_q9, std_list_q9 = process_quarter_data("Q9")
data_q10, std_list_q10 = process_quarter_data("Q10")
data_q11, std_list_q11 = process_quarter_data("Q11")
data_q12, std_list_q12 = process_quarter_data("Q12")
data_q13, std_list_q13 = process_quarter_data("Q13")
data_q14, std_list_q14 = process_quarter_data("Q14")
data_q15, std_list_q15 = process_quarter_data("Q15")
data_q16, std_list_q16 = process_quarter_data("Q16")

(print(data_q4))
# Out:
#         Materials    Scores       Source
# 0           Steel  7.203125  from_Survey
# 1       Aluminium  6.296875  from_Survey
# 2        Titanium  7.671875  from_Survey
# 3           Glass  2.828125  from_Survey
# 4            Wood  4.812500  from_Survey
# 5   Thermoplastic  4.437500  from_Survey
# 6       Elastomer  3.218750  from_Survey
# 7       Thermoset  4.640625  from_Survey
# 8       Composite  6.984375  from_Survey
# 9           Steel  9.000000     from_LLM
# 10      Aluminium  7.000000     from_LLM
# 11       Titanium  8.000000     from_LLM
# 12          Glass  2.000000     from_LLM
# 13           Wood  6.000000     from_LLM
# 14  Thermoplastic  7.000000     from_LLM
# 15      Elastomer  5.000000     from_LLM
# 16      Thermoset  7.000000     from_LLM
# 17      Composite  8.000000     from_LLM

# %%
fig, axs = plt.subplots(4, 4, figsize=(20, 20))

color_palette = sns.color_palette("colorblind")

df_bar = pd.DataFrame(data_q1[:len(materials)], columns=['Materials', 'Scores', 'Source'])
df_llm = pd.DataFrame(data_q1[len(materials):], columns=['Materials', 'Scores', 'Source'])

# Plot the bar chart with the colorblind-friendly palette
# axs[0,0].barplot(x='Materials', y='Scores', hue='Source', data=data_q1[:len(materials)], palette=color_palette, yerr=std_list_q1[:len(materials)])
sns.barplot(ax=axs[0, 0], x='Materials', y='Scores', hue='Source', data=df_bar, palette=color_palette, yerr=std_list_q1[:len(materials)])

# Plot the scatter plot with the colorblind-friendly palette
# axs[0,0].scatterplot(x='Materials', y='Scores', hue='Source', data=data_q1[len(materials):], palette="Set2", s=100)
sns.scatterplot(ax=axs[0, 0], x='Materials', y='Scores', hue='Source', data=df_llm, palette="Set2", s=100)


# axs[0, 0].xlabel('Materials', fontsize=12)
# axs[0, 0].ylabel('Scores', fontsize=12)
# axs[0, 0].ylim(0,10)
# axs[0, 0].title('Question 1 (Kitchen Utensil Grip-Lightweight)', fontsize=16)
# axs[0, 0].xticks(rotation=45, ha='right')
# axs[0, 0].legend()
plt.tight_layout()
plt.show()

# %%
rows, cols = 4,4

fig, axs = plt.subplots(rows, cols, figsize=(60, 60))

color_palette = sns.color_palette("colorblind")

questions = ["Question 1", "Question 2", "Question 3", "Question 4", "Question 5", "Question 6", "Question 7", "Question 8", "Question 9", "Question 10", "Question 11", "Question 12", "Question 13", "Question 14", "Question 15", "Question 16"]

df_list = [data_q1, data_q2, data_q3, data_q4, data_q5, data_q6, data_q7, data_q8, data_q9, data_q10, data_q11, data_q12, data_q13, data_q14, data_q15, data_q16]
std_list = [std_list_q1, std_list_q2, std_list_q3, std_list_q4, std_list_q5, std_list_q6, std_list_q7, std_list_q8, std_list_q9, std_list_q10, std_list_q11, std_list_q12, std_list_q13, std_list_q14, std_list_q15, std_list_q16]
for i in range(rows):
    for j in range(cols):
        ax = axs[i, j]
        sns.barplot(ax=ax, x='Materials', y='Scores', hue='Source', data=df_list[i*4+j][:len(materials)], palette=color_palette, yerr=std_list[i*4+j][:len(materials)])
        sns.scatterplot(ax=ax, x='Materials', y='Scores', hue='Source', data=df_list[i*4+j][len(materials):], palette="Set2", s=100)
        ax.set_title(questions[i*4+j])
        ax.set_xticklabels(materials, rotation=45)
        ax.set_xlabel('Materials', fontsize=12)
        ax.set_ylabel('Scores', fontsize=12)
plt.ylim(0,10)

plt.tight_layout()
plt.show()

# %% [markdown]
# Start New Notebook
